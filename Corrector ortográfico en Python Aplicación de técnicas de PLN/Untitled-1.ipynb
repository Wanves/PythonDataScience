# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
open('textos_articulo.txt', 'r', encoding='utf-8')
# Out:
# <_io.TextIOWrapper name='textos_articulo.txt' mode='r' encoding='utf-8'>

# %%
with open('textos_articulo.txt', 'r', encoding='utf-8') as f:
    articulos = f.read()
print(articulos[:500])
# Out:
# "HTTP: Diferencias entre GET y POST "
# 2020-10-21
# "Vea las diferencias entre los métodos GET y POST de HTTP. Consulta la funcionalidad de cada uno y cuándo usarlos en la web."
# "yuri-oliveira"
# "yuri.oliveira@alura.com.br"
# "front-end"
#
# Cuando vamos a acceder a un sistema web, es bastante común pasar por una pantalla de inicio de sesión, en la que ponemos nuestras credenciales para acceder al sistema.
# Estas informaciones deben ser confidenciales, sin embargo, cuando intenté iniciar sesión en una ap

# %%
len(articulos)
# Out:
# 288071

# %%
articulos.split()
# Out:
# ['"HTTP:',
#  'Diferencias',
#  'entre',
#  'GET',
#  'y',
#  'POST',
#  '"',
#  '2020-10-21',
#  '"Vea',
#  'las',
#  'diferencias',
#  'entre',
#  'los',
#  'métodos',
#  'GET',
#  'y',
#  'POST',
#  'de',
#  'HTTP.',
#  'Consulta',
#  'la',
#  'funcionalidad',
#  'de',
#  'cada',
#  'uno',
#  'y',
#  'cuándo',
#  'usarlos',
#  'en',
#  'la',
#  'web."',
#  '"yuri-oliveira"',
#  '"yuri.oliveira@alura.com.br"',
#  '"front-end"',
#  'Cuando',
#  'vamos',
#  'a',
#  'acceder',
#  'a',
#  'un',
#  'sistema',
#  'web,',
#  'es',
#  'bastante',
#  'común',
#  'pasar',
#  'por',
#  'una',
#  'pantalla',
#  'de',
#  'inicio',
#  'de',
#  'sesión,',
#  'en',
#  'la',
#  'que',
#  'ponemos',
#  'nuestras',
#  'credenciales',
#  'para',
#  'acceder',
#  'al',
#  'sistema.',
#  'Estas',
#  'informaciones',
#  'deben',
#  'ser',
#  'confidenciales,',
#  'sin',
#  'embargo,',
#  'cuando',
#  'intenté',
#  'iniciar',
#  'sesión',
#  'en',
#  'una',
#  'aplicación',
#  'web',
#  'que',
# ...

# %%
texto_ejemplo = 'Hola Juan, ¿qué tal?'
print(len(texto_ejemplo))
palabras = texto_ejemplo.split()
print(len(palabras))
print(palabras)
# Out:
# 20
# 4
# ['Hola', 'Juan,', '¿qué', 'tal?']

# %%
texto_ejemplo = 'Hola Juan, ¿qué tal?'
print(len(texto_ejemplo))
tokens = texto_ejemplo.split()
print(len(tokens))
print(palabras)
# Out:
# 20
# 4
# ['Hola', 'Juan,', '¿qué', 'tal?']

# %% [markdown]
# Corrector Ortográfico

# %%
open('textos_articulo.txt', 'r',  encoding='utf-8')
# Out:
# <_io.TextIOWrapper name='textos_articulo.txt' mode='r' encoding='utf-8'>

# %%
with open('textos_articulo.txt', 'r', encoding='utf-8') as f:
    articulos = f.read()
print(articulos[:500])
# Out:
# "HTTP: Diferencias entre GET y POST "
# 2020-10-21
# "Vea las diferencias entre los métodos GET y POST de HTTP. Consulta la funcionalidad de cada uno y cuándo usarlos en la web."
# "yuri-oliveira"
# "yuri.oliveira@alura.com.br"
# "front-end"
#
# Cuando vamos a acceder a un sistema web, es bastante común pasar por una pantalla de inicio de sesión, en la que ponemos nuestras credenciales para acceder al sistema.
# Estas informaciones deben ser confidenciales, sin embargo, cuando intenté iniciar sesión en una ap

# %% [markdown]
# Lo que aprendimos en esta aula:
#
# El concepto de Procesamiento de Lenguaje Natural (PLN o NLP)
# En qué consiste un corrector ortográfico
# Cómo leer un archivo de texto usando python
# Separar las palabras usando split()

# %% [markdown]
# Tokenización

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
texto_ejemplo = 'Hola Juan, ¿qué tal?'
print(len(texto_ejemplo))
tokens = texto_ejemplo.split()
print(len(tokens))
print(palabras)
# Out:
# 20
# 4
# ['Hola', 'Juan,', '¿qué', 'tal?']

# %%
palabras_separadas = nltk.tokenize.word_tokenize(texto_ejemplo)
print(palabras_separadas)
# Out:
# ['Hola', 'Juan', ',', '¿qué', 'tal', '?']

# %%
from nltk.tokenize.toktok import ToktokTokenizer

# %%
toktok = ToktokTokenizer()
palabras_separadas = toktok.tokenize(texto_ejemplo)
print(palabras_separadas)
# Out:
# ['Hola', 'Juan', ',', '¿', 'qué', 'tal', '?']

# %%
len(palabras_separadas)
# Out:
# 7

# %% [markdown]
# Excluyendo caracteres y puntuaciones

# %%
def separa_palabras(lista_tokens):
    lista_palabras = []
    for token in lista_tokens:
        if token.isalpha():
            lista_palabras.append(token)
            
    return lista_palabras

# %%
separa_palabras(palabras_separadas)
# Out:
# ['Hola', 'Juan', 'qué', 'tal']

# %% [markdown]
# Contando palabras del corpus

# %%
palabras_separadas = toktok.tokenize(articulos)
lista_palabras = separa_palabras(palabras_separadas)

# %%
print(f'La cantidad de palabras en el corpus es de: {len(lista_palabras)}')
# Out:
# La cantidad de palabras en el corpus es de: 40052

# %%
lista_palabras[:20]
# Out:
# ['HTTP',
#  'Diferencias',
#  'entre',
#  'GET',
#  'y',
#  'POST',
#  'Vea',
#  'las',
#  'diferencias',
#  'entre',
#  'los',
#  'métodos',
#  'GET',
#  'y',
#  'POST',
#  'de',
#  'Consulta',
#  'la',
#  'funcionalidad',
#  'de']

# %% [markdown]
# Normalizando y eliminando duplicados

# %%
def normalizar(lista_palabras):
    lista_normalizada = []
    for palabra in lista_palabras:
       lista_normalizada.append(palabra.lower())
    return lista_normalizada

# %%
palabras_normalizadas = normalizar(lista_palabras)
print(palabras_normalizadas[:20])
# Out:
# ['http', 'diferencias', 'entre', 'get', 'y', 'post', 'vea', 'las', 'diferencias', 'entre', 'los', 'métodos', 'get', 'y', 'post', 'de', 'consulta', 'la', 'funcionalidad', 'de']

# %%
palabras_unicas = set(palabras_normalizadas)
palabras_unicas
# Out:
# {'int',
#  'compañías',
#  'constantes',
#  'constructor',
#  'ya',
#  'lineal',
#  'complementaré',
#  'desees',
#  'botones',
#  'niños',
#  'use',
#  'mantenerlo',
#  'formulario',
#  'mostrar',
#  'profundizarte',
#  'consecuencias',
#  'eres',
#  'concreto',
#  'producir',
#  'pagada',
#  'minutos',
#  'intellij',
#  'preparar',
#  'conocí',
#  'ser',
#  'definidas',
#  'estandarizado',
#  'que',
#  'diferentes',
#  'tipos',
#  'llegar',
#  'practicidad',
#  'cercanas',
#  'definición',
#  'otra',
#  'mejorando',
#  'lunar',
#  'activo',
#  'cp',
#  'internaste',
#  'strong',
#  'entrada',
#  'almeida',
#  'cambiar',
#  'trabajos',
#  'incluyeron',
#  'agencias',
#  'e',
#  'cambie',
#  'credenciales',
#  'listado',
#  'además',
#  'después',
#  'límites',
#  'necesitaban',
#  'pulgadas',
#  'clima',
#  'encabezados',
#  'indicándonos',
#  'utilizarlos',
#  'opté',
#  'visible',
#  'ilusión',
#  'hereda',
#  'empezó',
#  'sacar',
#  'desarrolladores',
#  'implementaciones',
# ...

# %%
len(palabras_unicas)
# Out:
# 5101

# %% [markdown]
# Lo que aprendimos en esta aula:
#
# El concepto de tokenización
# A realizar el proceso de tokenización con las bibliotecas NLTK y toktok
# Separar caracteres alfabéticos de caracteres especiales con isalpha()
# Contar caracteres y palabras usando len()
# Proceso de Normalización con lower()
# Eliminar duplicados y repetidos con set()

# %% [markdown]
# Operación de Adición

# %%
import string
letras = string.ascii_lowercase + 'áéíóúAÁÉIÍOÓUÚ'
print(letras)
# Out:
# abcdefghijklmnopqrstuvwxyzáéíóúAÁÉIÍOÓUÚ

# %%
def adicionar_letras(partes):
    letras = string.ascii_lowercase + 'áéíóúAÁÉIÍOÓUÚ'
    nuevas_palabras = []
    for  I, D in partes:
        for letra in letras:
            nuevas_palabras.append(I + letra + D)
    return nuevas_palabras

def  generar_palabras(palabra):
    partes = []
    for i in range(len(palabra)+1):
        partes.append((palabra[:i] ,palabra[i:]))
    palabra_generadas = adicionar_letras(partes) 
    return palabra_generadas

# %%
# palabra = 'lgica'
# palabra_generadas = generar_palabras(palabra)
# print(palabra_generadas)

# %%
def corrector(palabra):
    palabra_generadas = generar_palabras(palabra)
    palabra_corregida = max(palabra_generadas, key=probabilidad)
    return palabra_corregida

# %% [markdown]
# Corrector

# %%
frecuencia = nltk.FreqDist(palabras_normalizadas)
frecuencia.most_common(10)
total_palabras = len(palabras_normalizadas)
print(total_palabras)
# Out:
# 40052

# %%
def probabilidad(palabra_generada):
    return frecuencia[palabra_generada] / total_palabras

# %%
corrector('lógic')
# Out:
# 'lógica'

# %% [markdown]
# Lo que aprendimos en esta aula:
#
# A construir un algoritmo capaz de corregir palabras que tienen una letra faltante
# Implementar la función de adición de letras y separación de palabras
# Implementar la función max() para seleccionar la palabra con mayor probabilidad de aparecer en el corpus
# A calcular la distribución de frecuencia de las palabras el corpus con nltk.FreqDist

# %% [markdown]
# Evaluador

# %%
def crear_datos_prueba(nombre_archivo):
    lista_pruebas = []
    f = open('palabras_pruebas.txt', 'r', encoding='utf-8')
    for fila in f:
        palabra_correcta, palabra_incorrecta = fila.split()
        lista_pruebas.append((palabra_correcta, palabra_incorrecta))
    f.close()    
    return lista_pruebas

lista_pruebas = crear_datos_prueba('palabras_pruebas.txt')
lista_pruebas
# Out:
# [('podemos', 'pyodemos'),
#  ('ese', 'esje'),
#  ('ya', 'yra'),
#  ('nuestro', 'nouestro'),
#  ('son', 'sons'),
#  ('de', 'des'),
#  ('mucho', 'muicho'),
#  ('imagen', 'imajem'),
#  ('su', 'sua'),
#  ('también', 'tambén'),
#  ('el', 'em'),
#  ('hacer', 'hazer'),
#  ('tenemos', 'tenemfs'),
#  ('esa', 'easa'),
#  ('cuando', 'quando'),
#  ('vamos', 'vamvos'),
#  ('sobre', 'hsobre'),
#  ('java', 'sjava'),
#  ('ahora', 'ahorah'),
#  ('está', 'essta'),
#  ('cada', 'céda'),
#  ('mismo', 'mizmo'),
#  ('nos', 'noz'),
#  ('forma', 'fobma'),
#  ('sea', 'sia'),
#  ('entonces', 'entoncez'),
#  ('crear', 'cear'),
#  ('código', 'cóeigo'),
#  ('caso', 'casío'),
#  ('ejemplo', 'ejempplo'),
#  ('tienes', 'tienez'),
#  ('usuario', 'usuirio'),
#  ('datos', 'fatos'),
#  ('python', 'pgthon'),
#  ('nuestra', 'nuestraz'),
#  ('así', 'azi'),
#  ('tener', 'tenner'),
#  ('hasta', 'asta'),
#  ('bien', 'biem'),
#  ('diseño', 'diseñho'),
#  ('trabajo', 'trabaju'),
#  ('fue', 'fueu'),
#  ('apenas', 'apenaz'),
# ...

# %%
def evaluador(pruebas):
    numero_palabras = len(pruebas)
    aciertos = 0
    for palabra_correcta, palabra_incorrecta in pruebas:
        palabra_corregida = corrector(palabra_incorrecta)
        if palabra_corregida == palabra_correcta:
            aciertos += 1
    tasa_acierto = aciertos*100/ numero_palabras
    print(f'La tasa de acierto es: {round(tasa_acierto, 2)}% de {numero_palabras} palabras ')
    
evaluador(lista_pruebas)
# Out:
# La tasa de acierto es: 5.14% de 175 palabras

# %% [markdown]
# Lo que aprendimos en esta aula:
#
# A construir una función para evaluar la calidad de nuestro corrector
# Utilizamos una base de prueba para validar la calidad de nuestro corrector
# Calcular la tasa de asertividad de nuestro corrector

# %% [markdown]
# Operación de Eliminación

# %%
def eliminar_caracteres(partes):
    nuevas_palabras = []
    for  I, D in partes:
        nuevas_palabras.append(I +  D[1:])
    return nuevas_palabras

# %%
def  generar_palabras(palabra):
    partes = []
    for i in range(len(palabra)+1):
        partes.append((palabra[:i] ,palabra[i:]))
    palabra_generadas = adicionar_letras(partes) 
    palabra_generadas += eliminar_caracteres(partes)
    return palabra_generadas

# %%
print(generar_palabras('lóigica'))
# Out:
# ['alóigica', 'blóigica', 'clóigica', 'dlóigica', 'elóigica', 'flóigica', 'glóigica', 'hlóigica', 'ilóigica', 'jlóigica', 'klóigica', 'llóigica', 'mlóigica', 'nlóigica', 'olóigica', 'plóigica', 'qlóigica', 'rlóigica', 'slóigica', 'tlóigica', 'ulóigica', 'vlóigica', 'wlóigica', 'xlóigica', 'ylóigica', 'zlóigica', 'álóigica', 'élóigica', 'ílóigica', 'ólóigica', 'úlóigica', 'Alóigica', 'Álóigica', 'Élóigica', 'Ilóigica', 'Ílóigica', 'Olóigica', 'Ólóigica', 'Ulóigica', 'Úlóigica', 'laóigica', 'lbóigica', 'lcóigica', 'ldóigica', 'leóigica', 'lfóigica', 'lgóigica', 'lhóigica', 'lióigica', 'ljóigica', 'lkóigica', 'llóigica', 'lmóigica', 'lnóigica', 'loóigica', 'lpóigica', 'lqóigica', 'lróigica', 'lsóigica', 'ltóigica', 'luóigica', 'lvóigica', 'lwóigica', 'lxóigica', 'lyóigica', 'lzóigica', 'láóigica', 'léóigica', 'líóigica', 'lóóigica', 'lúóigica', 'lAóigica', 'lÁóigica', 'lÉóigica', 'lIóigica', 'lÍóigica', 'lOóigica', 'lÓóigica', 'lUóigica', 'lÚóigica', 'lóaigica', 'lóbigica', 'lócigica', '
# ...

# %%
evaluador(lista_pruebas)
# Out:
# La tasa de acierto es: 38.29% de 175 palabras

# %% [markdown]
# Lo que aprendimos en esta aula:
#
# A construir un algoritmo capaz de corregir palabras que tienen una letra extra o por demás
# Implementar la función de eliminación de caracteres

# %% [markdown]
# Operación de Alteración

# %%
def alterar_caracteres(partes):
    letras = string.ascii_lowercase + 'áéíóúAÁÉIÍOÓUÚ'
    nuevas_palabras = []
    for  I, D in partes:
        for letra in letras:
            nuevas_palabras.append(I + letra + D[1:])
    return nuevas_palabras

# %%
def  generar_palabras(palabra):
    partes = []
    for i in range(len(palabra)+1):
        partes.append((palabra[:i] ,palabra[i:]))
    palabra_generadas = adicionar_letras(partes) 
    palabra_generadas += eliminar_caracteres(partes)
    palabra_generadas += alterar_caracteres(partes)
    return palabra_generadas

# %%
print(generar_palabras('lígica'))
# Out:
# ['alígica', 'blígica', 'clígica', 'dlígica', 'elígica', 'flígica', 'glígica', 'hlígica', 'ilígica', 'jlígica', 'klígica', 'llígica', 'mlígica', 'nlígica', 'olígica', 'plígica', 'qlígica', 'rlígica', 'slígica', 'tlígica', 'ulígica', 'vlígica', 'wlígica', 'xlígica', 'ylígica', 'zlígica', 'álígica', 'élígica', 'ílígica', 'ólígica', 'úlígica', 'Alígica', 'Álígica', 'Élígica', 'Ilígica', 'Ílígica', 'Olígica', 'Ólígica', 'Ulígica', 'Úlígica', 'laígica', 'lbígica', 'lcígica', 'ldígica', 'leígica', 'lfígica', 'lgígica', 'lhígica', 'liígica', 'ljígica', 'lkígica', 'llígica', 'lmígica', 'lnígica', 'loígica', 'lpígica', 'lqígica', 'lrígica', 'lsígica', 'ltígica', 'luígica', 'lvígica', 'lwígica', 'lxígica', 'lyígica', 'lzígica', 'láígica', 'léígica', 'líígica', 'lóígica', 'lúígica', 'lAígica', 'lÁígica', 'lÉígica', 'lIígica', 'lÍígica', 'lOígica', 'lÓígica', 'lUígica', 'lÚígica', 'líagica', 'líbgica', 'lícgica', 'lídgica', 'líegica', 'lífgica', 'líggica', 'líhgica', 'líigica', 'líjgica', 'líkgic
# ...

# %%
evaluador(lista_pruebas)
# Out:
# La tasa de acierto es: 64.57% de 175 palabras

# %% [markdown]
# Lo que aprendimos en esta aula:
#
# Evaluamos un nuevo escenario de error en el proceso de digitación
# Implementamos la función cambiar letras, cuando uno de los caracteres de la palabra fue alterado involuntariamente por otro carácter
# Calculamos nuevamente la tasa de asertividad para medir la mejora gradual de la asertividad

# %% [markdown]
# Operación Invirtiendo las letras

# %%
def invertir_caracteres(partes):
    nuevas_palabras = []
    for  I, D in partes:
        if len(D) > 1:
            nuevas_palabras.append(I  + D[1] + D[0] + D[2:])
    return nuevas_palabras

# %%
def  generar_palabras(palabra):
    partes = []
    for i in range(len(palabra)+1):
        partes.append((palabra[:i] ,palabra[i:]))
    palabra_generadas = adicionar_letras(partes) 
    palabra_generadas += eliminar_caracteres(partes)
    palabra_generadas += alterar_caracteres(partes)
    palabra_generadas += invertir_caracteres(partes)
    return palabra_generadas

# %%
print(generar_palabras('lgóica'))
# Out:
# ['algóica', 'blgóica', 'clgóica', 'dlgóica', 'elgóica', 'flgóica', 'glgóica', 'hlgóica', 'ilgóica', 'jlgóica', 'klgóica', 'llgóica', 'mlgóica', 'nlgóica', 'olgóica', 'plgóica', 'qlgóica', 'rlgóica', 'slgóica', 'tlgóica', 'ulgóica', 'vlgóica', 'wlgóica', 'xlgóica', 'ylgóica', 'zlgóica', 'álgóica', 'élgóica', 'ílgóica', 'ólgóica', 'úlgóica', 'Algóica', 'Álgóica', 'Élgóica', 'Ilgóica', 'Ílgóica', 'Olgóica', 'Ólgóica', 'Ulgóica', 'Úlgóica', 'lagóica', 'lbgóica', 'lcgóica', 'ldgóica', 'legóica', 'lfgóica', 'lggóica', 'lhgóica', 'ligóica', 'ljgóica', 'lkgóica', 'llgóica', 'lmgóica', 'lngóica', 'logóica', 'lpgóica', 'lqgóica', 'lrgóica', 'lsgóica', 'ltgóica', 'lugóica', 'lvgóica', 'lwgóica', 'lxgóica', 'lygóica', 'lzgóica', 'lágóica', 'légóica', 'lígóica', 'lógóica', 'lúgóica', 'lAgóica', 'lÁgóica', 'lÉgóica', 'lIgóica', 'lÍgóica', 'lOgóica', 'lÓgóica', 'lUgóica', 'lÚgóica', 'lgaóica', 'lgbóica', 'lgcóica', 'lgdóica', 'lgeóica', 'lgfóica', 'lggóica', 'lghóica', 'lgióica', 'lgjóica', 'lgkóic
# ...

# %%
# Lista de palabras
palabras = ['algóica', 'blgóica', 'clgóica', 'dlgóica', 'elgóica', 'flgóica', 'glgóica', 'hlgóica', 'ilgóica', 'jlgóica', 'klgóica', 'llgóica', 'mlgóica', 'nlgóica', 'olgóica', 'plgóica', 'qlgóica', 'rlgóica', 'slgóica', 'tlgóica', 'ulgóica', 'vlgóica', 'wlgóica', 'xlgóica', 'ylgóica', 'zlgóica', 'álgóica', 'élgóica', 'ílgóica', 'ólgóica', 'úlgóica', 'Algóica', 'Álgóica', 'Élgóica', 'Ilgóica', 'Ílgóica', 'Olgóica', 'Ólgóica', 'Ulgóica', 'Úlgóica', 'lagóica', 'lbgóica', 'lcgóica', 'ldgóica', 'legóica', 'lfgóica', 'lggóica', 'lhgóica', 'ligóica', 'ljgóica', 'lkgóica', 'llgóica', 'lmgóica', 'lngóica', 'logóica', 'lpgóica', 'lqgóica', 'lrgóica', 'lsgóica', 'ltgóica', 'lugóica', 'lvgóica', 'lwgóica', 'lxgóica', 'lygóica', 'lzgóica', 'lágóica', 'légóica', 'lígóica', 'lógóica', 'lúgóica', 'lAgóica', 'lÁgóica', 'lÉgóica', 'lIgóica', 'lÍgóica', 'lOgóica', 'lÓgóica', 'lUgóica', 'lÚgóica', 'lgaóica', 'lgbóica', 'lgcóica', 'lgdóica', 'lgeóica', 'lgfóica', 'lggóica', 'lghóica', 'lgióica', 'lgjóica', 'lgkóica', 'lglóica', 'lgmóica', 'lgnóica', 'lgoóica', 'lgpóica', 'lgqóica', 'lgróica', 'lgsóica', 'ltgóica', 'lugóica', 'lvgóica', 'lwgóica', 'lxgóica', 'lygóica', 'lzgóica', 'lágóica', 'légóica', 'lígóica', 'lógóica', 'lúgóica', 'lAgóica', 'lÁgóica', 'lÉgóica', 'lIgóica', 'lÍgóica', 'lOgóica', 'lÓgóica', 'lUgóica', 'lÚgóica', 'lgaóica', 'lgbóica', 'lgcóica', 'lgdóica', 'lgeóica', 'lgfóica', 'lggóica', 'lghóica', 'lgióica', 'lgjóica', 'lgkóica', 'lglóica', 'lgmóica', 'lgnóica', 'lgoóica', 'lgpóica', 'lgqóica', 'lgróica', 'lgsóica', 'ltgóica', 'lugóica', 'lvgóica', 'lwgóica', 'lxgóica', 'lygóica', 'lzgóica', 'lágóica', 'légóica', 'lígóica', 'lógóica', 'lúgóica', 'lAgóica', 'lÁgóica', 'lÉgóica', 'lIgóica', 'lÍgóica', 'lOgóica', 'lÓgóica', 'lUgóica', 'lÚgóica', 'lgAica', 'lgÁica', 'lgÉica', 'lgIica', 'lgÍica', 'lgOica', 'lgÓica', 'lgUica', 'lgÚica', 'lgóaca', 'lgóbca', 'lgócca', 'lgódca', 'lgóeca', 'lgófca', 'lgógca', 'lgóhca', 'lgóica', 'lgójca', 'lgókca', 'lgólca', 'lgómca', 'lgónca', 'lgóoca', 'lgópca', 'lgóqca', 'lgórca', 'lgósca', 'lgótca', 'lgóuca', 'lgóvca', 'lgówca', 'lgóxca', 'lgóyca', 'lgózca', 'lgóáca', 'lgóéca', 'lgóíca', 'lgóóca', 'lgóúca', 'lgóAca', 'lgóÁca', 'lgóÉca', 'lgóIca', 'lgóÍca', 'lgóOca', 'lgóÓca', 'lgóUca', 'lgóÚca', 'lgóiaca', 'lgóibca', 'lgóicca', 'lgóidca', 'lgóieca', 'lgóifca', 'lgóigca', 'lgóihca', 'lgóiica', 'lgóijca', 'lgóikca', 'lgóilca', 'lgóimca', 'lgóinca', 'lgóioca', 'lgóipca', 'lgóiqca', 'lgóirca', 'lgóisca', 'lgóitca', 'lgóiuca', 'lgóivca', 'lgóiwca', 'lgóixca', 'lgóiyca', 'lgóizca', 'lgóiáca', 'lgóiéca', 'lgóiíca', 'lgóióca', 'lgóiúca', 'lgóiAca', 'lgóiÁca', 'lgóiÉca', 'lgóiIca', 'lgóiÍca', 'lgóiOca', 'lgóiÓca', 'lgóiUca', 'lgóiÚca', 'lgóicaa', 'lgóicab', 'lgóicac', 'lgóicad', 'lgóicae', 'lgóicaf', 'lgóicag', 'lgóicah', 'lgóicai', 'lgóicaj', 'lgóicak', 'lgóical', 'lgóicam', 'lgóican', 'lgóicao', 'lgóicap', 'lgóicaq', 'lgóicar', 'lgóicas', 'lgóicat', 'lgóicau', 'lgóicav', 'lgóicaw', 'lgóicax', 'lgóicay', 'lgóicaz', 'lgóicaá', 'lgóicaé', 'lgóicaí', 'lgóicaó', 'lgóicaú', 'lgóicaA', 'lgóicaÁ', 'lgóicaÉ', 'lgóicaI', 'lgóicaÍ', 'lgóicaO', 'lgóicaÓ', 'lgóicaU', 'lgóicaÚ', 'glóica', 'lógica', 'lgióca', 'lgócia', 'lgóiac']


posicion = palabras.index('lógica')
print(f"La palabra 'lógica' se encuentra en la posición: {posicion}")
# Out:
# La palabra 'lógica' se encuentra en la posición: 290

# %%
evaluador(lista_pruebas)
# Out:
# La tasa de acierto es: 65.71% de 175 palabras

# %% [markdown]
# Limitación del corrector

# %%
def evaluador(pruebas, vocabulario):
    numero_palabras = len(pruebas)
    aciertos = 0
    desconocidas = 0
    for palabra_correcta, palabra_incorrecta in pruebas:
        palabra_corregida = corrector(palabra_incorrecta)
        desconocidas += (palabra_correcta not in vocabulario)
        if palabra_corregida == palabra_correcta:
            aciertos += 1
    tasa_acierto = aciertos*100/ numero_palabras
    tasa_desconocidas = desconocidas*100/ numero_palabras
    print(f'La tasa de acierto es: {round(tasa_acierto, 2)}% de {numero_palabras} palabras ')
    print(f'La tasa de desconocidas es: {round(tasa_desconocidas, 2)}% de {numero_palabras} palabras ')
    
evaluador(lista_pruebas, palabras_unicas)
# Out:
# La tasa de acierto es: 65.71% de 175 palabras
# La tasa de desconocidas es: 12.0% de 175 palabras

# %% [markdown]
# Lo que aprendimos en esta aula:
#
# Finalizamos evaluando un cuarto escenario de error en el proceso de digitacion
# Implementamos la función invertir letras, cuando dos caracteres vienen invertidos en la palabra
# Calculamos la tasa final de asertividad de nuestro corrector
# Calculamos la tasa de palabras desconocidas, uno de los limitadores de la calidad de nuestro corrector
