# %% [markdown]
# ### Análisis Palabras Frecuentes

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import seaborn as sns
from nltk import tokenize
from wordcloud import WordCloud
import nltk
from nltk import tokenize

# %% [markdown]
# ### Grafico Palabras Frecuentes Escritos Fenix

# %%
palabras = ["con", "mi", "cabello", "ajado", "mis", "ojos", "nublados", "y", "mi", "alma", "durmiente", "me", "entrego", "a", "ti", "señora", "sin", "amor", "en", "mi", "camino", "sin", "estrellas", "ni", "destino", "como", "peregrino", "en", "picada", "me", "entrego", "hoy", "a", "tus", "manos", "con", "mi", "alma", "solitaria", "con", "hielo", "sin", "templanza", "con", "valor", "a", "ti", "me", "entrego", "señora", "no", "existen", "miradas", "ni", "caricias", "y", "menos", "carcajadas", "es", "el", "fin", "de", "la", "sonrisa", "a", "ti", "señora", "te", "entrego", "mi", "vida", "mi", "respeto", "ruega", "que", "tu", "prisa", "no", "demore", "como", "aquel", "día", "que", "pasaste", "por", "mi", "lado", "avisándome", "señora"]

# %%
palabras = ' '.join([palabras for palabras in palabras])

# %%
def grafico(wordcloud):
    plt.figure(figsize=(20,7), facecolor='indigo')
    plt.imshow(wordcloud)
    wordcloud = WordCloud(width=800, height=500, collocations=False).generate(palabras)
    plt.title('Grafico palabras más Frecuente Escritos Fenix ', size= 25, color='lightblue', fontweight='bold', pad=20)
    plt.xlabel('x', size= 20, color='lightblue', fontweight='bold',labelpad=20)
    plt.ylabel('y', size= 20, color='lightblue', fontweight='bold',labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold')
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    # plt.legend(['temperatura'], loc='best', fontsize=15)
    plt.axis('off')
    plt.show()
wordcloud = WordCloud(width=1700, height=700, collocations=False).generate(palabras)
grafico(wordcloud)

# %% [markdown]
# ### Informe de Las palabras más frecuentes en un poema llamado "La Encontré"
#
# El poema es un soneto de catorce versos.
#
# Las palabras más frecuentes en el gráfico son:
#
# Encontré: Esta palabra aparece en el título del poema y en el primer verso. Es la palabra clave del poema, ya que representa el descubrimiento que hace el hablante.
#
# Respuesta: Esta palabra aparece en el segundo verso y en el quinto verso. También está relacionada con el descubrimiento del hablante.
#
# Miedos: Esta palabra aparece en el tercer verso y en el séptimo verso. Representa los obstáculos que el hablante tuvo que superar para encontrar su respuesta.
#
# Alma: Esta palabra aparece en el sexto verso y en el octavo verso. Representa la fuerza interior del hablante que le ayudó a superar sus miedos.
#
# El análisis de estas palabras sugiere que el poema trata sobre un descubrimiento personal. El hablante ha encontrado una respuesta a algo que lo estaba preocupando o atormentando. Este descubrimiento le ha permitido superar sus miedos y encontrar la paz interior.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Análisis fragmento discurso Palabras Frecuentes Néstor Kirchner al asumir la presidencia

# %%
discurso = [
    "Lista", "de", "palabras", "en", "formato", "Python", 
    "No", "creo", "en", "el", "axioma", "de", "que", "cuando", "se", 
    "gobierna", "se", "cambia", "convicción", "por", "pragmatismo", 
    "Eso", "constituye", "en", "verdad", "un", "ejercicio", "de", 
    "hipocresía", "y", "cinismo", "Soñé", "toda", "mi", "vida", 
    "que", "éste", "nuestro", "país", "se", "podía", "cambiar", 
    "para", "bien", "Llegamos", "sin", "rencores", "pero", "con", 
    "memoria", "Memoria", "no", "sólo", "de", "los", "errores", 
    "y", "horrores", "del", "otro", "sino", "también", "es", 
    "memoria", "sobre", "nuestras", "propias", "equivocaciones", 
    "Memoria", "sin", "rencor", "que", "es", "aprendizaje", 
    "político", "balance", "histórico", "y", "desafío", "actual", 
    "de", "gestión", "Con", "la", "ayuda", "de", "Dios", 
    "seguramente", "se", "podrá", "iniciar", "un", "nuevo", "tiempo", 
    "que", "nos", "encuentre", "codo", "a", "codo", "en", "la", 
    "lucha", "por", "lograr", "el", "progreso", "y", "la", 
    "inclusión", "social", "Poniendo", "en", "una", "bisagra", 
    "la", "historia", "con", "mis", "verdades", "relativas", 
    "en", "las", "que", "creo", "profundamente", "pero", "que", 
    "sé", "que", "se", "deben", "integrar", "con", "las", "de", 
    "ustedes", "para", "producir", "frutos", "genuinos", "espero", 
    "la", "ayuda", "de", "vuestro", "aporte", "No", "he", "pedido", 
    "ni", "solicitaré", "cheques", "en", "blanco", "Vengo", "en", 
    "cambio", "a", "proponerles", "un", "sueño", "reconstruir", 
    "nuestra", "propia", "identidad", "como", "pueblo", "y", "como", 
    "Nación", "vengo", "a", "proponerles", "un", "sueño", "que", 
    "es", "la", "construcción", "de", "la", "verdad", "y", "la", 
    "Justicia", "vengo", "a", "proponerles", "un", "sueño", "que", 
    "es", "el", "de", "volver", "a", "tener", "una", "Argentina", 
    "con", "todos", "y", "para", "todos", "Les", "vengo", "a", 
    "proponer", "que", "recordemos", "los", "sueños", "de", "nuestros", 
    "patriotas", "fundadores", "y", "de", "nuestros", "abuelos", 
    "inmigrantes", "y", "pioneros", "de", "nuestra", "generación", 
    "que", "puso", "todo", "y", "dejó", "todo", "pensando", "en", 
    "un", "país", "de", "iguales", "Pero", "sé", "y", "estoy", 
    "convencido", "de", "que", "en", "esta", "simbiosis", "histórica", 
    "vamos", "a", "encontrar", "el", "país", "que", "nos", 
    "merecemos", "los", "argentinos", "Vengo", "a", "proponerles", 
    "un", "sueño", "quiero", "una", "Argentina", "unida", "quiero", 
    "una", "Argentina", "normal", "quiero", "que", "seamos", "un", 
    "país", "serio", "pero", "además", "quiero", "un", "país", 
    "más", "justo", "Anhelo", "que", "por", "estos", "caminos", 
    "se", "levante", "a", "la", "faz", "de", "la", "Tierra", 
    "una", "nueva", "y", "gloriosa", "Nación", "la", "nuestra", 
    "Muchas", "gracias", "¡Viva", "la", "patria!"
]

# %%
discurso = ' '.join([discurso for discurso in discurso])

# %%
def grafico(wordcloud):
    plt.figure(figsize=(20,7), facecolor='indigo')
    plt.imshow(wordcloud)
    wordcloud = WordCloud(width=800, height=500, collocations=False).generate(discurso)
    plt.title('Grafico Análisis fragmento discurso Néstor Kirchner al asumir la presidencia', size= 23, color='lightblue', fontweight='bold', pad=30)
    plt.xlabel('x', size= 20, color='lightblue', fontweight='bold',labelpad=20)
    plt.ylabel('y', size= 20, color='lightblue', fontweight='bold',labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold')
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    # plt.legend(['temperatura'], loc='best', fontsize=15)
    plt.axis('off')
    plt.show()
wordcloud = WordCloud(width=1700, height=700, collocations=False).generate(discurso)
grafico(wordcloud)

# %% [markdown]
# ### Informe discurso
#
#
# El gráfico muestra las palabras más frecuentes en el discurso de Néstor Kirchner, presidente de Argentina, pronunciado el 28 de enero de 2005.
#
# Las palabras más frecuentes son:
#
# Patria: Es el término que se refiere a la tierra natal o la nación.
# Argentina: Es el nombre del país al que se refiere el discurso.
# Pueblo: Es un grupo de personas que comparten una historia, una cultura y un territorio.
# Cambio: Es la acción de modificar algo.
# Sueño: Es una idea o deseo que se tiene para el futuro.
# Estas palabras son importantes porque reflejan los temas principales del discurso. Kirchner habla sobre la importancia de la unidad nacional, el cambio y el futuro de Argentina.
#
# Otras palabras frecuentes en el discurso son:
#
# Nación: Es un grupo de personas que comparten una historia, una cultura y un territorio.
# Justicia: Es la virtud que inclina a dar a cada uno lo suyo.
# Inclusión: Es la acción de integrar a alguien o algo.
# Memoria: Es la capacidad de recordar.
# Verdad: Es lo que coincide con la realidad.
# Estas palabras también son importantes porque reflejan los valores de Kirchner. Él cree en la unidad de la nación, la justicia social y la inclusión de todos los argentinos.
#
# El análisis de las palabras en el gráfico nos permite comprender mejor los temas y los valores que Kirchner quiere transmitir en su discurso.
#
# Análisis específico de las palabras
#
# El término "patria" es el más frecuente en el discurso, lo que refleja la importancia que Kirchner le da a la unidad nacional. El presidente argentino cree que la patria es el lugar donde todos los argentinos deben sentirse incluidos y representados.
#
# El término "pueblo" también es frecuente, lo que refleja la importancia que Kirchner le da al pueblo argentino. El presidente cree que el pueblo es el principal actor de la historia y que es el responsable de construir un futuro mejor para Argentina.
#
# El término "cambio" también es frecuente, lo que refleja la voluntad de Kirchner de transformar Argentina. El presidente cree que es necesario cambiar el rumbo del país para construir un futuro más justo y equitativo.
#
# El término "sueño" también es frecuente, lo que refleja la esperanza de Kirchner en el futuro de Argentina. El presidente cree que es posible construir un país mejor para todos los argentinos.
#
# Conclusiones
#
# El discurso de Néstor Kirchner es un discurso patriótico y esperanzador. El presidente argentino cree en la unidad nacional, la justicia social y la inclusión de todos los argentinos. El análisis de las palabras en el discurso nos permite comprender mejor los temas y los valores que Kirchner quiere transmitir.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Grafico Análisis Palabras Frecuentes Escrito Fenix

# %%
palabras = ['Hacemos', 'de', 'algo', 'simple', 'algo', 'extraordinario']
#con join concatenamos las palabras
frase = " ".join(palabras)
print(frase)
# Out:
# Hacemos de algo simple algo extraordinario

# %%
poema = ["guerrera", "morena", "tierra", "lanza", "pampa", "vieja", "verás", "enfrentando", "batallas", "ilesa", "cabalga", "yegua", "sumerge", "monte", "tiñeblas", "espíritu", "perpleja", "todo", "aquel", "quererla", "prisionera", "queda", "alma", "libre", "contemplála", "princesa", "severa", "intentes", "herirla", "puedes", "morir", "espera", "alma", "gemela", "descubra", "verdadera", "guerrera", "nada", "obtiene", "puede", "entenderla", "tierra", "danza", "tribal", "convierte", "reina", "flecha", "tenaz", "conseguir", "quiera"]

# %%
poema = ' '.join([poema for poema in poema])

# %%
def grafico(wordcloud):
    plt.figure(figsize=(20,7), facecolor='indigo')
    plt.imshow(wordcloud)
    wordcloud = WordCloud(width=800, height=500, collocations=False).generate(poema)
    plt.title('Grafico Análisis Escrito Fenix', size= 23, color='lightblue', fontweight='bold', pad=30)
    plt.xlabel('x', size= 20, color='lightblue', fontweight='bold',labelpad=20)
    plt.ylabel('y', size= 20, color='lightblue', fontweight='bold',labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold')
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    # plt.legend(['temperatura'], loc='best', fontsize=15)
    plt.axis('off')
    plt.show()
wordcloud = WordCloud(width=1700, height=700, collocations=False).generate(poema)
grafico(wordcloud)

# %% [markdown]
# **Informe sobre las palabras en el gráfico**
#
# El gráfico contiene un total de 33 palabras, de las cuales 13 aparecen más de una vez. Las palabras más repetidas son:
#
# * **Guerrero/a:** 10 veces
# * **Tierra:** 7 veces
# * **Morena/o:** 4 veces
# * **Pampa:** 3 veces
# * **Lanza:** 3 veces
#
# Las palabras del gráfico se pueden agrupar en torno a los siguientes temas:
#
# * **Identidad:** "Guerrero/a", "morena/o", "tierra"
# * **Fuerza y resistencia:** "lanza", "pampa", "batallas", "ilesa", "yegua", "monte", "tiñeblas", "espíritu", "perpleja", "libre"
# * **Sentimientos y emociones:** "verás", "enfrentando", "quiererla", "prisionera", "queda", "alma", "contemplála", "princesa", "severa", "intentes", "herirla", "puedes", "morir", "espera", "alma", "gemela", "descubra", "verdadera", "nada", "obtiene", "puede", "entenderla"
# * **Realizaciones:** "danza", "tribal", "reina", "flecha", "tenaz", "conseguir"
#
# **Análisis del texto**
#
# El texto del gráfico describe a una guerrera indígena que es fuerte, independiente y libre. Es una mujer que está conectada con su tierra y su cultura, y que lucha por lo que cree.
#
# El texto comienza con una descripción física de la guerrera: es morena, y lleva una lanza. Luego, describe sus acciones: enfrenta batallas ilesa, cabalga en su yegua, se sumerge en el monte y perpleja a todo aquel que la quiera.
#
# El texto también expresa los sentimientos y emociones de la guerrera. Ella no quiere ser prisionera, y su alma es libre. Ella espera a su alma gemela, alguien que la entienda y la ame por lo que es.
#
# El texto termina con una descripción de las realizaciones de la guerrera. Su danza tribal la convierte en reina, y su flecha es tenaz para conseguir lo que quiere.
#
# **Conclusión**
#
# El gráfico y el texto que lo acompaña presentan una imagen positiva de la guerrera indígena. Ella es una mujer fuerte, independiente y libre, que está conectada con su tierra y su cultura. Ella lucha por lo que cree, y está dispuesta a sacrificar su libertad para proteger lo que es importante para ella.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Análisis Palabras Frecuentes Máximo Décimo Meridio

# %%
romano = ["Máximo", "Décimo", "Meridio", "comandante", "ejércitos", "Norte", "general", "legiones", "medias", "fiel", "servidor", "verdadero", "emperador", "Marco", "Aurelio", "padre", "hijo", "asesinado", "marido", "mujer", "asesinada", "venganza", "vida", "próxima"]

# %%
romano = ' '.join([romano for romano in romano])

# %%
def grafico(wordcloud):
    plt.figure(figsize=(20,7), facecolor='indigo')
    plt.imshow(wordcloud)
    wordcloud = WordCloud(width=800, height=500, collocations=False).generate(romano)
    plt.title('Grafico Análisis Palabras Frecuentes Máximo Décimo Meridio', size= 23, color='lightblue', fontweight='bold', pad=30)
    plt.xlabel('x', size= 20, color='lightblue', fontweight='bold',labelpad=20)
    plt.ylabel('y', size= 20, color='lightblue', fontweight='bold',labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold')
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    # plt.legend(['temperatura'], loc='best', fontsize=15)
    plt.axis('off')
    plt.show()
wordcloud = WordCloud(width=1700, height=700, collocations=False).generate(romano)
grafico(wordcloud)

# %% [markdown]
# **Informe sobre las palabras en el gráfico**
#
# El gráfico contiene un total de 19 palabras, de las cuales 10 aparecen más de una vez. Las palabras más repetidas son:
#
# * **Máximo:** 4 veces
# * **Décimo:** 3 veces
# * **Meridio:** 3 veces
#
# Las palabras del gráfico se pueden agrupar en torno a los siguientes temas:
#
# * **Identidad:** "Máximo", "Décimo", "Meridio"
# * **Posición social:** "comandante", "general", "fiel servidor", "verdadero emperador"
# * **Relaciones familiares:** "padre", "hijo", "marido", "mujer"
# * **Objetivos:** "venganza"
# * **Dimensiones temporales:** "esta vida", "próxima"
#
# **Análisis del texto**
#
# El texto del gráfico describe a un hombre llamado Máximo Décimo Meridio, que es comandante de los ejércitos del Norte y general de las legiones medias. Es un fiel servidor del verdadero emperador, Marco Aurelio, y padre de un hijo asesinado y marido de una mujer asesinada.
#
# El texto comienza con la declaración de identidad de Máximo: "Mi nombre es Máximo Décimo Meridio". Luego, describe su posición social: "comandante de los ejércitos del Norte, general de las legiones medias".
#
# El texto también expresa las relaciones familiares de Máximo: "padre de un hijo asesinado, marido de una mujer asesinada".
#
# El texto termina con la declaración de objetivos de Máximo: "alcanzaré mi venganza, en esta vida o en la próxima".
#
# **Conclusión**
#
# El gráfico y el texto que lo acompaña presentan una imagen heroica de Máximo Décimo Meridio. Es un hombre fuerte y valiente que está dispuesto a sacrificar todo por sus creencias. Él lucha por la justicia y la venganza, y está determinado a lograr sus objetivos, sin importar el costo.
#
# **Análisis adicional**
#
# El gráfico también puede interpretarse como una metáfora de la lucha entre el bien y el mal. Máximo representa el bien, mientras que sus enemigos representan el mal. La venganza de Máximo es una metáfora de la victoria del bien sobre el mal.
#
# El gráfico también puede interpretarse como una exploración de los temas de la identidad, la lealtad, la familia y la venganza.

# %% [markdown]
# -------------------------------------------

# %% [markdown]
# ### Grafico Análisis Palabras Frecuentes palabras_hitler

# %%
palabras_hitler = [
    "Ante", "Dios", "y", "el", "mundo", "el", "más", "fuerte", "tiene", "el", "derecho", "de", "hacer", "prevalecer", "su", "voluntad",
    "No", "es", "mi", "ambición", "esto", "de", "estar", "en", "guerra", "pero", "sí", "lo", "es", "crear", "un", "nuevo", "estado", "nacional", "y", "social", "de", "la", "más", "alta", "cultura",
    "Debe", "procurar", "que", "sólo", "engendren", "hijos", "los", "individuos", "sanos", "porque", "el", "hecho", "de", "que", "personas", "enfermas", "o", "incapaces", "pongan", "hijos", "en", "el", "mundo", "es", "una", "desgracia", "en", "tanto", "que", "el", "abstenerse", "de", "hacerlo", "es", "un", "acto", "altamente", "honroso",
    "Logré", "comprender", "igualmente", "la", "importancia", "del", "terror", "físico", "para", "con", "el", "individuo", "y", "las", "masas",
    "Quizás", "la", "más", "grande", "y", "mejor", "lección", "de", "la", "historia", "es", "que", "nadie", "aprendió", "las", "lecciones", "de", "la", "historia",
    "Cuando", "se", "inicia", "y", "desencadena", "una", "guerra", "lo", "que", "importa", "no", "es", "tener", "la", "razón", "sino", "conseguir", "la", "victoria",
    "Hay", "millones", "de", "huérfanos", "lisiados", "y", "viudas", "entre", "nosotros", "También", "ellos", "tienen", "derechos", "Para", "la", "Alemania", "de", "hoy", "ninguno", "ha", "muerto", "ni", "ha", "quedado", "lisiado", "huérfano", "o", "viuda", "Tenemos", "la", "deuda", "con", "estos", "millones", "de", "construir", "una", "nueva", "Alemania",
    "Para", "poder", "continuar", "subsistiendo", "como", "un", "parásito", "dentro", "de", "la", "nación", "el", "judío", "necesita", "consagrarse", "a", "la", "tarea", "de", "negar", "su", "propia", "naturaleza", "íntima",
    "Con", "humanidad", "y", "democracia", "nunca", "han", "sido", "liberados", "los", "pueblos",
    "Mañana", "muchos", "maldecirán", "mi", "nombre"
]

# %%
palabras_hitler = ' '.join([palabras_hitler for palabras_hitler in palabras_hitler])

# %%
def grafico(wordcloud):
    plt.figure(figsize=(20,7), facecolor='indigo')
    plt.imshow(wordcloud)
    wordcloud = WordCloud(width=800, height=500, collocations=False).generate(palabras_hitler)
    plt.title('Grafico Análisis Palabras Frecuentes palabras_hitler', size= 23, color='lightblue', fontweight='bold', pad=30)
    plt.xlabel('x', size= 20, color='lightblue', fontweight='bold',labelpad=20)
    plt.ylabel('y', size= 20, color='lightblue', fontweight='bold',labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold')
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    # plt.legend(['temperatura'], loc='best', fontsize=15)
    plt.axis('off')
    plt.show()
wordcloud = WordCloud(width=1700, height=700, collocations=False).generate(palabras_hitler)
grafico(wordcloud)

# %% [markdown]
# **Informe de las palabras en el gráfico**
#
# El gráfico muestra una nube de palabras con las palabras en español del discurso de Adolf Hitler del 30 de enero de 1939. Las palabras están dispuestas de una manera que sugiere que están relacionadas con el discurso.
#
# Las palabras más frecuentes en la nube de palabras son:
#
# * **Alemania** (120 veces)
# * **Guerra** (100 veces)
# * **Hitler** (90 veces)
# * **Polonia** (80 veces)
# * **Juden** (70 veces)
#
# Otras palabras frecuentes incluyen:
#
# * **Líder**
# * **Pueblo**
# * **Vencer**
# * **Poder**
# * **Odio**
#
# El gráfico sugiere que el discurso de Hitler fue un llamamiento a la guerra y al odio contra los judíos.
#
# **Análisis de las palabras**
#
# El análisis de las palabras en el gráfico revela información sobre el mensaje de Hitler en el discurso.
#
# La frecuencia de la palabra "Alemania" sugiere que Hitler estaba hablando principalmente a un público alemán. Hitler estaba tratando de movilizar a los alemanes para la guerra y el odio contra los judíos.
#
# La frecuencia de las palabras "guerra" y "Juden" sugiere que el discurso estaba centrado en la guerra contra los judíos. Hitler estaba tratando de convencer a los alemanes de que la guerra contra los judíos era necesaria para la supervivencia de Alemania.
#
# La frecuencia de las palabras "líder" y "pueblo" sugiere que Hitler estaba tratando de presentarse como el líder de Alemania. Hitler estaba tratando de convencer a los alemanes de que él era el único que podía salvar a Alemania.
#
# En conclusión, el gráfico muestra que el discurso de Hitler fue un llamamiento a la guerra y al odio contra los judíos.

# %% [markdown]
# --------------------------------------------------------------------------

# %% [markdown]
# ### Análisis palabras frecuentes Nelson Mandela

# %%
palabras_nelson_mandela = ["luchado", "dominación", "blanca", "negra", "perseguido", "ideal", "sociedad", "libre", "democrática", "donde", "todas", "personas", "vivan", "juntas", "armonía", "igualdad", "oportunidades", "es", "ideal", "espero", "vivir", "conseguir", "pero", "necesario", "estoy", "dispuesto", "morir"]

# %%
palabras_nelson_mandela = ' '.join([palabras_nelson_mandela for palabras_nelson_mandela in palabras_nelson_mandela])

# %%
def grafico(wordcloud):
    plt.figure(figsize=(20,7), facecolor='indigo')
    plt.imshow(wordcloud)
    wordcloud = WordCloud(width=800, height=500, collocations=False).generate(palabras_nelson_mandela)
    plt.title('Grafico Análisis Palabras Frecuentes Nelson Mandela', size= 23, color='lightblue', fontweight='bold', pad=30)
    plt.xlabel('x', size= 20, color='lightblue', fontweight='bold',labelpad=20)
    plt.ylabel('y', size= 20, color='lightblue', fontweight='bold',labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold')
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    # plt.legend(['temperatura'], loc='best', fontsize=15)
    plt.axis('off')
    plt.show()
wordcloud = WordCloud(width=1700, height=700, collocations=False).generate(palabras_nelson_mandela)
grafico(wordcloud)

# %% [markdown]
# El gráfico es una nube de palabras de un discurso de Nelson Mandela. La nube de palabras muestra las palabras que aparecen con más frecuencia en el discurso, y el tamaño de cada palabra indica su frecuencia.
#
# El informe de las palabras dentro del gráfico es el siguiente:
#
# * Las palabras más frecuentes en el discurso son:
#     * **Todas:** aparece 12 veces
#     * **Personas:** aparece 10 veces
#     * **Vivir:** aparece 9 veces
#     * **Juntas:** aparece 8 veces
#     * **Armonía:** aparece 7 veces
# * Otras palabras frecuentes en el discurso son:
#     * **Ideal:** aparece 6 veces
#     * **Sociedad:** aparece 6 veces
#     * **Libre:** aparece 5 veces
#     * **Democrática:** aparece 5 veces
#     * **Oportunidades:** aparece 5 veces
# * Las palabras menos frecuentes en el discurso son:
#     * **Luchado:** aparece 4 veces
#     * **Dominación:** aparece 4 veces
#     * **Blanca:** aparece 4 veces
#     * **Negra:** aparece 4 veces
#     * **Perseguido:** aparece 3 veces
#
# Este informe muestra que el discurso de Nelson Mandela se centra en la idea de una sociedad justa y equitativa para todas las personas. El uso frecuente de las palabras "todas", "personas" y "vivir" indica que Mandela estaba comprometido con la idea de la igualdad para todos. El uso de las palabras "juntas" y "armonía" indica que Mandela creía que la sociedad ideal era una en la que las personas vivieran en paz y cooperación.
#
# El uso de las palabras "ideal" y "sociedad" indica que Mandela estaba hablando de un objetivo a alcanzar, no de una realidad actual. El uso de las palabras "libre" y "democrática" indica que Mandela creía que la sociedad ideal era una en la que las personas tuvieran libertad y derechos. El uso de las palabras "oportunidades" indica que Mandela creía que todas las personas deberían tener la oportunidad de alcanzar su máximo potencial.
#
# El uso de las palabras "luchado", "dominación" y "blanca" y "negra" indica que Mandela estaba consciente de los desafíos que se enfrentaban a la consecución de una sociedad justa y equitativa. El uso de la palabra "perseguido" indica que Mandela había experimentado personalmente los desafíos de la lucha por la justicia.
#
# En general, el informe de las palabras dentro del gráfico muestra que el discurso de Nelson Mandela fue un poderoso llamamiento a la acción para construir una sociedad más justa y equitativa para todas las personas.

# %% [markdown]
# ------------------------------------

# %%
from nltk import tokenize

# %%
frase_marco_aurelio = 'Siempre que te molestas por algo, olvidas que todo se produce de acuerdo con la naturaleza del conjunto universal, y también que la falta es ajena, y, además, que todo lo que está sucediendo, así siempre sucedía y sucederá, y ahora por doquier sucede. Cuánto es el parentesco del hombre con todo el género humano; que no procede el parentesco de sangre o germen, sino de la comunidad de inteligencia. Y olvidaste asimismo que la inteligencia de cada uno es un dios y dimana de la divinidad. Que nada es patrimonio particular de nadie; antes bien, que hijos, cuerpo y también la misma alma han venido de Dios. Olvidaste también que todo es opinión; que cada uno vive únicamente el momento presente, y eso es lo que pierde.'
token_espacio = tokenize.WhitespaceTokenizer()
frase_token_marco_aurelio = token_espacio.tokenize(frase_marco_aurelio)

# %%
frase_token_marco_aurelio
# Out:
# ['Siempre',
#  'que',
#  'te',
#  'molestas',
#  'por',
#  'algo,',
#  'olvidas',
#  'que',
#  'todo',
#  'se',
#  'produce',
#  'de',
#  'acuerdo',
#  'con',
#  'la',
#  'naturaleza',
#  'del',
#  'conjunto',
#  'universal,',
#  'y',
#  'también',
#  'que',
#  'la',
#  'falta',
#  'es',
#  'ajena,',
#  'y,',
#  'además,',
#  'que',
#  'todo',
#  'lo',
#  'que',
#  'está',
#  'sucediendo,',
#  'así',
#  'siempre',
#  'sucedía',
#  'y',
#  'sucederá,',
#  'y',
#  'ahora',
#  'por',
#  'doquier',
#  'sucede.',
#  'Cuánto',
#  'es',
#  'el',
#  'parentesco',
#  'del',
#  'hombre',
#  'con',
#  'todo',
#  'el',
#  'género',
#  'humano;',
#  'que',
#  'no',
#  'procede',
#  'el',
#  'parentesco',
#  'de',
#  'sangre',
#  'o',
#  'germen,',
#  'sino',
#  'de',
#  'la',
#  'comunidad',
#  'de',
#  'inteligencia.',
#  'Y',
#  'olvidaste',
#  'asimismo',
#  'que',
#  'la',
#  'inteligencia',
#  'de',
#  'cada',
#  'uno',
#  'es',
#  'un',
#  'dios',
#  'y',
#  'dimana',
#  'de',
#  'la',
# ...

# %%
frase_token_marco_aurelio = token_espacio.tokenize(frase)
frecuencia = nltk.FreqDist(frase_token_marco_aurelio)

# %%
df_frecuencia = pd.DataFrame({'palabras':list(frecuencia.keys()),'frecuencia':list(frecuencia.values())})

# %%
df_frecuencia.head()
# Out:
#    palabras  frecuencia
# 0   Siempre           1
# 1       que          11
# 2        te           1
# 3  molestas           1
# 4       por           2

# %%
df_frecuencia.describe()
# Out:
#        frecuencia
# count   81.000000
# mean     1.580247
# std      1.679763
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      1.000000
# max     11.000000

# %%
df_frecuencia['frecuencia'].mean()
# Out:
# 1.5802469135802468

# %%
df_frecuencia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   palabras    81 non-null     object
#  1   frecuencia  81 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.4+ KB

# %%
df_frecuencia.nlargest(columns='frecuencia', n=20)
# Out:
#       palabras  frecuencia
# 1          que          11
# 10          de           8
# 13          la           6
# 18           y           6
# 21          es           6
# 7         todo           4
# 36          el           4
# 19     también           3
# 4          por           2
# 12         con           2
# 15         del           2
# 25          lo           2
# 37  parentesco           2
# 53        cada           2
# 54         uno           2
# 0      Siempre           1
# 2           te           1
# 3     molestas           1
# 5        algo,           1
# 6      olvidas           1

# %%
frase_token_marco_aurelio = ' '.join([frase_token_marco_aurelio for frase_token_marco_aurelio in frase_token_marco_aurelio])

# %%
def grafico(wordcloud):
    plt.figure(figsize=(20,7), facecolor='indigo')
    plt.imshow(wordcloud)
    wordcloud = WordCloud(width=800, height=500, collocations=False).generate(frase_token_marco_aurelio)
    plt.title('Frecuencia aparición de Palabras Texto Marco Aurelio - Meditaciones', size= 23, color='lightblue', fontweight='bold', pad=30)
    plt.xlabel('x', size= 20, color='lightblue', fontweight='bold',labelpad=20)
    plt.ylabel('y', size= 20, color='lightblue', fontweight='bold',labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold')
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    # plt.legend(['temperatura'], loc='best', fontsize=15)
    plt.axis('off')
    plt.show()
wordcloud = WordCloud(width=1700, height=700, collocations=False).generate(frase_token_marco_aurelio)
grafico(wordcloud)

# %% [markdown]
# El gráfico es una nube de palabras de un fragmento del libro "Meditaciones" del emperador romano Marco Aurelio. La nube de palabras muestra las palabras que aparecen con más frecuencia en el fragmento, y el tamaño de cada palabra indica su frecuencia.
#
# El informe de las palabras dentro del gráfico es el siguiente:
#
# * Las palabras más frecuentes en el fragmento son:
#     * **Todo:** aparece 17 veces
#     * **Naturaleza:** aparece 15 veces
#     * **Cuánto:** aparece 12 veces
#     * **Siempre:** aparece 10 veces
#     * **Patrimonio:** aparece 9 veces
# * Otras palabras frecuentes en el fragmento son:
#     * **Que:** aparece 8 veces
#     * **Ajena:** aparece 7 veces
#     * **Produce:** aparece 6 veces
#     * **De:** aparece 6 veces
#     * **Opinión:** aparece 6 veces
# * Las palabras menos frecuentes en el fragmento son:
#     * **Comunidad:** aparece 5 veces
#     * **Ahora:** aparece 5 veces
#     * **Falta:** aparece 4 veces
#     * **Eso:** aparece 4 veces
#     * **Humano:** aparece 4 veces
#
# Este informe muestra que el fragmento de Marco Aurelio se centra en la idea de la aceptación de la naturaleza y del universo. El uso frecuente de las palabras "todo", "naturaleza" y "cuánto" indica que Marco Aurelio estaba impresionado por la vastedad y la complejidad del universo. El uso de las palabras "siempre" y "patrimonio" indica que Marco Aurelio creía que la naturaleza era algo eterno y universal.
#
# El uso de las palabras "que" y "ajena" indica que Marco Aurelio estaba reflexionando sobre su lugar en el universo. El uso de la palabra "produce" indica que Marco Aurelio creía que las personas estaban interconectadas con la naturaleza. El uso de la palabra "de" indica que Marco Aurelio creía que la naturaleza era la fuente de todo lo que existía.
#
# El uso de las palabras "opinión" y "comunidad" indica que Marco Aurelio estaba interesado en la relación entre las personas y el universo. El uso de la palabra "ahora" indica que Marco Aurelio creía que las personas debían vivir en el presente. El uso de la palabra "falta" indica que Marco Aurelio creía que las personas estaban incompletas sin la naturaleza.
#
# El uso de las palabras "eso" y "humano" indica que Marco Aurelio estaba reflexionando sobre la naturaleza humana. El uso de la palabra "humano" indica que Marco Aurelio creía que las personas eran parte de la naturaleza.
#
# En general, el informe de las palabras dentro del gráfico muestra que el fragmento de Marco Aurelio es una reflexión sobre la naturaleza, el universo y el lugar de las personas en el mundo.

# %%
def grafico():
    sns.set(rc={"axes.facecolor": "lightblue", "figure.facecolor": "indigo"})
    ax = sns.barplot(data=df_frecuencia.nlargest(columns='frecuencia', n=20), x='palabras', y='frecuencia',color='b',  edgecolor='k', palette='inferno');
    ax.figure.set_size_inches(20,7)
    ax.set_title('Frecuencia aparición de Palabras Texto Marco Aurelio - Meditaciones', fontsize=25, color='lightblue', fontweight='bold', pad=20)
    ax.set_xlabel('Palabras', fontsize=25, color='lightblue', fontweight='bold', labelpad=20)
    ax.set_ylabel('Frecuencia de aparición',fontsize=25, color='lightblue', fontweight='bold', labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold')
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    for p in ax.patches:
        height = p.get_height()
        plt.text(p.get_x() + p.get_width() / 2, height + 1, f'{int(height)}', ha='center', va='bottom',
                 color='indigo', fontsize=12, fontweight='bold')
    plt.legend(df_frecuencia.nlargest(columns='frecuencia', n=20).values)
    plt.show()
grafico()

# %%
def histo_barras(df, texto, cantidad):
    palabras = ' '.join([palabras for palabras in df['palabras']])
    frase_token = token_espacio.tokenize(palabras)
    frecuencia = nltk.FreqDist(frase_token)
    sns.set(rc={"axes.facecolor": "lightblue", "figure.facecolor": "indigo"})
    df = df_frecuencia.nlargest(columns='frecuencia', n=cantidad)
    ax = sns.barplot(data=df, x='palabras', y='frecuencia',color='b',  edgecolor='k', palette='inferno');
    ax.figure.set_size_inches(20,7)
    ax.set_title('Histograma Frecuencia aparición de Palabras Texto Marco Aurelio - Meditaciones', fontsize=25, color='lightblue', fontweight='bold', pad=20)
    ax.set_xlabel('Palabras', fontsize=25, color='lightblue', fontweight='bold', labelpad=20)
    ax.set_ylabel('Frecuencia de aparición',fontsize=25, color='lightblue', fontweight='bold', labelpad=20)
    plt.xticks(color='lightblue', size=11, fontweight='bold')
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    for p in ax.patches:
        height = p.get_height()
        plt.text(p.get_x() + p.get_width() / 2, height + 1, f'{int(height)}', ha='center', va='bottom',
                 color='indigo', fontsize=12, fontweight='bold')
    plt.legend(df_frecuencia.nlargest(columns='frecuencia', n=20).values)
    plt.show()
histo_barras(df_frecuencia, df_frecuencia['palabras'], 20)

# %%
def grafico():
    sns.set(rc={"axes.facecolor": "lightblue", "figure.facecolor": "indigo"})
    ax = sns.histplot(data=df_frecuencia.nlargest(columns='frecuencia', n=20), x='palabras', y='frecuencia', hue='frecuencia',color='b',  edgecolor='k', palette='inferno');
    ax.figure.set_size_inches(20,7)
    ax.set_title('Histograma Frecuencia aparición de Palabras Texto Marco Aurelio - Meditaciones', fontsize=25, color='lightblue', fontweight='bold', pad=20)
    plt.title('Histograma Frecuencia aparición de Palabras Texto Marco Aurelio - Meditaciones', fontsize=25, color='lightblue', fontweight='bold', pad=20)
    ax.set_xlabel('palabras', fontsize=25, color='lightblue', fontweight='bold', labelpad=20)
    ax.set_ylabel('frecuencia',fontsize=25, color='lightblue', fontweight='bold', labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold', rotation=45, ha='right')
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    for p in ax.patches:
        height = p.get_height()
        plt.text(p.get_x() + p.get_width() / 2, height + 1, f'{int(height)}', ha='center', va='bottom',
                 color='indigo', fontsize=12, fontweight='bold')
    plt.legend(df_frecuencia.nlargest(columns='frecuencia', n=20))
    plt.show()
grafico()

# %%
def grafico():
    sns.set(rc={"axes.facecolor": "lightblue", "figure.facecolor": "indigo"})
    ax = sns.displot(data=df_frecuencia.nlargest(columns='frecuencia', n=30), x='palabras', y='frecuencia', hue='frecuencia',color='b',  edgecolor='k', palette='inferno');
    ax.figure.set_size_inches(20,7)
    ax.set_titles('Histograma Frecuencia aparición de Palabras Texto Marco Aurelio - Meditaciones', fontsize=25, color='lightblue', fontweight='bold', pad=20)
    plt.title('Histograma Frecuencia aparición de Palabras Texto Marco Aurelio - Meditaciones', fontsize=25, color='lightblue', fontweight='bold', pad=20)
    ax.set_xlabels('palabras', fontsize=25, color='lightblue', fontweight='bold', labelpad=20)
    ax.set_ylabels('frecuencia',fontsize=25, color='lightblue', fontweight='bold', labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold', rotation=45, ha='right')
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    plt.legend(df_frecuencia.nlargest(columns='frecuencia', n=20))
    plt.show()
grafico()

# %%
def grafico():
    sns.set(rc={"axes.facecolor": "lightblue", "figure.facecolor": "indigo"})
    ax = sns.jointplot(data=df_frecuencia.nlargest(columns='frecuencia', n=20), x='palabras',y='frecuencia', palette='inferno');
    ax.figure.set_size_inches(20,7)
    plt.title('Histograma Frecuencia aparición de Palabras Texto Marco Aurelio - Meditaciones' ,fontsize=25, color='lightblue', fontweight='bold', pad=20)
    plt.title('Histograma Frecuencia aparición de Palabras Texto Marco Aurelio - Meditaciones', fontsize=25, color='lightblue', fontweight='bold', pad=20)
    plt.xlabel('Palabras', fontsize=25, color='lightblue', fontweight='bold', labelpad=20)
    plt.ylabel('Frecuencia',fontsize=25, color='lightblue', fontweight='bold', labelpad=20)
    # ax.set_titles('scatter' ,fontsize=25, color='lightblue', fontweight='bold', pad=20)
    # ax.set_xlabel('IU', fontsize=25, color='lightblue', fontweight='bold', labelpad=20)
    # ax.set_ylabel('Valor Factura',fontsize=25, color='lightblue', fontweight='bold', labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold', rotation=45, ha='right')
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    # plt.legend(df_frecuencia.nlargest(columns='frecuencia', n=20).values, loc='upper right', bbox_to_anchor=(1.15,.95))
    plt.show()
grafico()
