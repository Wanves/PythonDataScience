# %% [markdown]
# Gráficos

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('figure', figsize = (15,5))

# %%
datos = pd.read_csv('alquiler_residencial_sin_outliers.csv', sep=';')
datos.head()
# Out:
#    Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  Mantenimiento  \
# 0  Casa   Lurigancho        2         0       1   100   7000.0            0.0
# 1  Casa        Lince        4         1       2   400  12000.0            0.0
# 2  Casa  Santa Anita        2         0       0    51   1500.0           50.0
# 3  Casa     San Luis        8         3       5   259   7000.0            0.0
# 4  Casa        Breña        1         0       0    33   1200.0            0.0
#
#    Impuesto  Valor Bruto  Valor m2  Valor Bruto m2 Tipo Agrupado
# 0       0.0       7000.0     70.00           70.00          Casa
# 1       0.0      12000.0     30.00           30.00          Casa
# 2       0.0       1550.0     29.41           30.39          Casa
# 3       0.0       7000.0     27.03           27.03          Casa
# 4       0.0       1200.0     36.36           36.36          Casa

# %%
area = plt.figure(figsize=(20,8))
area.set_facecolor('orange')

g1 = area.add_subplot(2,2,1)
g2 = area.add_subplot(2,2,2)
g3 = area.add_subplot(2,2,3)
g4 = area.add_subplot(2,2,4)

g1.scatter(data=datos, x='Valor', y='Area')
g1.set_title('Valor por area')

g2.hist(data=datos,x='Valor')
g2.set_title('Histograma')

datos_g3 = datos['Valor'].sample(100)
datos_g3.index = range(datos_g3.shape[0])
g3.plot(datos_g3)
g3.set_title('Muestra')

grupo = datos.groupby('Tipo')['Valor']
label = grupo.mean().index
valores = grupo.mean().values
g4.bar(label, valores)
g4.set_title('Valor medio por tipo')

plt.show()

# %%
area.savefig('grafico.png', dpi = 300, bbox_inches ='tight')

# %% [markdown]
# En esta aula, aprendimos:
#
# Cómo identificar y eliminar outliers con box plot
# Cómo hacer un gráfico de pizza con la aplicación del método pie(), de la biblioteca matplotlib
