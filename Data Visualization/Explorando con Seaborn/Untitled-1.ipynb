# %% [markdown]
# Análisis de Datos

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
datos = pd.read_csv('credit_card.csv')
datos
# Out:
#       LIMIT_BAL CHECKING_ACCOUNT          EDUCATION MARRIAGE  AGE  \
# 0          6022              Yes       2.University  Married   24
# 1         36132              Yes       2.University   Single   26
# 2         27099              Yes       2.University   Single   34
# 3         15055              Yes       2.University  Married   37
# 4        150550               No  3.Graduate School   Single   29
# ...         ...              ...                ...      ...  ...
# 1495      54198              Yes  3.Graduate School   Single   27
# 1496      45165               No       2.University  Married   55
# 1497      78286               No  3.Graduate School   Single   34
# 1498       6022               No       2.University  Married   44
# 1499     183671               No  3.Graduate School   Single   31
#
#          BILL_AMT     PAY_AMT  DEFAULT
# 0        934.0122      0.0000        1
# 1        519.3975      0.0000        1
# 2       4223.5297    457.0698        0
# ...

# %%
datos.head()
# Out:
#    LIMIT_BAL CHECKING_ACCOUNT          EDUCATION MARRIAGE  AGE     BILL_AMT  \
# 0       6022              Yes       2.University  Married   24     934.0122
# 1      36132              Yes       2.University   Single   26     519.3975
# 2      27099              Yes       2.University   Single   34    4223.5297
# 3      15055              Yes       2.University  Married   37   14522.9563
# 4     150550               No  3.Graduate School   Single   29  124060.1253
#
#       PAY_AMT  DEFAULT
# 0      0.0000        1
# 1      0.0000        1
# 2    457.0698        0
# 3    602.2000        0
# 4  16560.5000        0

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LIMIT_BAL         1500 non-null   int64
#  1   CHECKING_ACCOUNT  1500 non-null   object
#  2   EDUCATION         1500 non-null   object
#  3   MARRIAGE          1500 non-null   object
#  4   AGE               1500 non-null   int64
#  5   BILL_AMT          1500 non-null   float64
#  6   PAY_AMT           1500 non-null   float64
#  7   DEFAULT           1500 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 93.9+ KB

# %%
datos.columns
# Out:
# Index(['LIMIT_BAL', 'CHECKING_ACCOUNT', 'EDUCATION', 'MARRIAGE', 'AGE',
#        'BILL_AMT', 'PAY_AMT', 'DEFAULT'],
#       dtype='object')

# %%
dict_columnas = {
    'LIMIT_BAL':'Limite',        
    'CHECKING_ACCOUNT':'Cuenta_corriente',  
    'EDUCATION':'Escolaridad',       
    'MARRIAGE':'Estado_civil',         
    'AGE':'Edad',                 
    'BILL_AMT':'Valor_factura',          
    'PAY_AMT':'Valor_pago',           
    'DEFAULT':'Moroso'  
}
datos.rename(columns = dict_columnas, inplace=True)
datos
# Out:
#       Limite Cuenta_corriente        Escolaridad Estado_civil  Edad  \
# 0       6022              Yes       2.University      Married    24
# 1      36132              Yes       2.University       Single    26
# 2      27099              Yes       2.University       Single    34
# 3      15055              Yes       2.University      Married    37
# 4     150550               No  3.Graduate School       Single    29
# ...      ...              ...                ...          ...   ...
# 1495   54198              Yes  3.Graduate School       Single    27
# 1496   45165               No       2.University      Married    55
# 1497   78286               No  3.Graduate School       Single    34
# 1498    6022               No       2.University      Married    44
# 1499  183671               No  3.Graduate School       Single    31
#
#       Valor_factura  Valor_pago  Moroso
# 0          934.0122      0.0000       1
# 1          519.3975      0.0000       1
# ...

# %%
tarjetas = datos

# %%
tarjetas.head()
# Out:
#    Limite Cuenta_corriente        Escolaridad Estado_civil  Edad  \
# 0    6022              Yes       2.University      Married    24
# 1   36132              Yes       2.University       Single    26
# 2   27099              Yes       2.University       Single    34
# 3   15055              Yes       2.University      Married    37
# 4  150550               No  3.Graduate School       Single    29
#
#    Valor_factura  Valor_pago  Moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas['Cuenta_corriente'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
dict_cuenta = {
    'Yes': 'Si',
    'No' : 'No'
}

datos['Cuenta_corriente'].map(dict_cuenta)
# Out:
# 0       Si
# 1       Si
# 2       Si
# 3       Si
# 4       No
#         ..
# 1495    Si
# 1496    No
# 1497    No
# 1498    No
# 1499    No
# Name: Cuenta_corriente, Length: 1500, dtype: object

# %%
tarjetas.head()
# Out:
#    Limite Cuenta_corriente        Escolaridad Estado_civil  Edad  \
# 0    6022              Yes       2.University      Married    24
# 1   36132              Yes       2.University       Single    26
# 2   27099              Yes       2.University       Single    34
# 3   15055              Yes       2.University      Married    37
# 4  150550               No  3.Graduate School       Single    29
#
#    Valor_factura  Valor_pago  Moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas['Cuenta_corriente'] = tarjetas['Cuenta_corriente'].map(dict_cuenta)

# %%
tarjetas
# Out:
#       Limite Cuenta_corriente        Escolaridad Estado_civil  Edad  \
# 0       6022               Si       2.University      Married    24
# 1      36132               Si       2.University       Single    26
# 2      27099               Si       2.University       Single    34
# 3      15055               Si       2.University      Married    37
# 4     150550               No  3.Graduate School       Single    29
# ...      ...              ...                ...          ...   ...
# 1495   54198               Si  3.Graduate School       Single    27
# 1496   45165               No       2.University      Married    55
# 1497   78286               No  3.Graduate School       Single    34
# 1498    6022               No       2.University      Married    44
# 1499  183671               No  3.Graduate School       Single    31
#
#       Valor_factura  Valor_pago  Moroso
# 0          934.0122      0.0000       1
# 1          519.3975      0.0000       1
# ...

# %%
tarjetas['Escolaridad'].unique()
# Out:
# array(['2.University', '3.Graduate School', '1.High School'], dtype=object)

# %%
dict_escolaridad = {
    '2.University':'2.Universidad',
    '3.Graduate School':'3.Pos-graduación',
    '1.High School':'1.Colegio'
}

# %%
tarjetas['Escolaridad'] = tarjetas['Escolaridad'].map(dict_escolaridad)

# %%
tarjetas.head()
# Out:
#    Limite Cuenta_corriente       Escolaridad Estado_civil  Edad  \
# 0    6022               Si     2.Universidad      Married    24
# 1   36132               Si     2.Universidad       Single    26
# 2   27099               Si     2.Universidad       Single    34
# 3   15055               Si     2.Universidad      Married    37
# 4  150550               No  3.Pos-graduación       Single    29
#
#    Valor_factura  Valor_pago  Moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas['Estado_civil'].unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
dict_estado_civil ={
    'Married':'Casado/a',
    'Single':'Soltero/a'
}

# %%
tarjetas['Estado_civil'] = tarjetas['Estado_civil'].map(dict_estado_civil)

# %%
tarjetas.head()
# Out:
#    Limite Cuenta_corriente       Escolaridad Estado_civil  Edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    Valor_factura  Valor_pago  Moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %% [markdown]
# Lo que aprendimos en esta aula:
#
# Hacer upload de archivo csv para Google Colab. Importamos pandas e importamos la base de datos con la que vamos a trabajar en el curso: credit_card.csv.
# Conocimos nuestra base de datos y las variables que vamos a analizar en clase.
# Por cuestiones didácticas decidimos hacer la traducción al español de las variables categóricas en la base que se encontraban en inglés.
# Guardamos nuestra base de datos con el nombre de tarjetas.

# %% [markdown]
# --------------------------------------------------------------------

# %% [markdown]
#  Importando Seaborn y análisis de distribución

# %%
tarjetas.head(2)
# Out:
#    Limite Cuenta_corriente    Escolaridad Estado_civil  Edad  Valor_factura  \
# 0    6022               Si  2.Universidad     Casado/a    24       934.0122
# 1   36132               Si  2.Universidad    Soltero/a    26       519.3975
#
#    Valor_pago  Moroso
# 0         0.0       1
# 1         0.0       1

# %% [markdown]
# Análisis 1

# %%
sns.displot(data=tarjetas, x='Limite',hue='Moroso', color='indigo', kde=True);

# %%
sns.displot(data=tarjetas, x='Edad',hue='Escolaridad', color='indigo', kde=True);

# %%
sns.displot(data=tarjetas, x='Valor_factura',hue='Escolaridad', color='indigo', kde=True);

# %% [markdown]
# Análisis 2

# %%
tarjetas['iu'] = tarjetas['Valor_factura'] /  tarjetas['Limite']

# %%
tarjetas.head()
# Out:
#    Limite Cuenta_corriente       Escolaridad Estado_civil  Edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    Valor_factura  Valor_pago  Moroso        iu
# 0       934.0122      0.0000       1  0.155100
# 1       519.3975      0.0000       1  0.014375
# 2      4223.5297    457.0698       0  0.155856
# 3     14522.9563    602.2000       0  0.964660
# 4    124060.1253  16560.5000       0  0.824046

# %%
sns.displot(data=tarjetas, x='iu',hue='Escolaridad', color='indigo', kde=True);

# %% [markdown]
# Hay un publico significativo que usan poco del límite que tienen disponible

# %% [markdown]
# Estilos y colores

# %%
sns.set_style('darkgrid')

# %%
plt.figure(figsize=(15,7))
sns.displot(data=tarjetas, x='iu',hue='Escolaridad', color='indigo', kde=True);

# %%
plt.figure(figsize=(15,7))
sns.displot(data=tarjetas, x='iu',hue='Escolaridad', color='indigo', kde=True, col='Escolaridad');

# %%
plt.figure(figsize=(15,7))
sns.displot(data=tarjetas, x='iu',hue='Escolaridad', kde=True,palette='inferno');

# %%
plt.figure(figsize=(15,7))
sns.displot(data=tarjetas, x='iu',hue='Escolaridad', kde=True,palette='inferno',col='Escolaridad');

# %% [markdown]
# Lo que aprendimos en esta aula:
#
# Importamos Seaborn para analizar de forma gráfica las variables que tenemos en nuestra base de datos.
# Construimos una nueva variable numérica en nuestra base de datos.
# Creamos un histograma para analizar variables en nuestra base de datos.
# Descubrimos los estilos y colores que Seaborn nos ofrece.

# %% [markdown]
# ------------------------------------------------

# %% [markdown]
# Análisis de variables categóricas

# %%
tarjetas.head()
# Out:
#    Limite Cuenta_corriente       Escolaridad Estado_civil  Edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    Valor_factura  Valor_pago  Moroso        iu
# 0       934.0122      0.0000       1  0.155100
# 1       519.3975      0.0000       1  0.014375
# 2      4223.5297    457.0698       0  0.155856
# 3     14522.9563    602.2000       0  0.964660
# 4    124060.1253  16560.5000       0  0.824046

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='Cuenta_corriente', data=tarjetas, hue='Moroso',palette='inferno');

# %%
plt.figure(figsize=(15,7))
sns.catplot(x='Estado_civil', y='Limite', data=tarjetas,palette='inferno')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3428\1994373959.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='Estado_civil', y='Limite', data=tarjetas,palette='inferno')

# %%
plt.figure(figsize=(15,7))
sns.catplot(x='Estado_civil', y='Limite', data=tarjetas,palette='inferno', hue='Moroso',dodge=True)

# %%
plt.figure(figsize=(15,7))
sns.swarmplot(x='Escolaridad', y='iu', data=tarjetas, palette='inferno');
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3428\1289475980.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='Escolaridad', y='iu', data=tarjetas, palette='inferno');
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 9.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 13.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# -------------------------------------------------

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data=tarjetas,x='Escolaridad', y='iu',palette='inferno');
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3428\3471451117.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=tarjetas,x='Escolaridad', y='iu',palette='inferno');

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data=tarjetas,x='Escolaridad', y='iu', hue='Moroso',palette='inferno');

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data=tarjetas,x='Escolaridad', y='iu', hue='Moroso',palette='bone');

# %%
plt.figure(figsize=(15,7))
sns.violinplot(data=tarjetas, x='Escolaridad', y='iu', palette='inferno');
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3428\224157610.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=tarjetas, x='Escolaridad', y='iu', palette='inferno');

# %%
plt.figure(figsize=(15,7))
sns.violinplot(data=tarjetas, x='Escolaridad', y='iu',hue='Moroso', palette='inferno');

# %%
tarjetas.head()
# Out:
#    Limite Cuenta_corriente       Escolaridad Estado_civil  Edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    Valor_factura  Valor_pago  Moroso        iu
# 0       934.0122      0.0000       1  0.155100
# 1       519.3975      0.0000       1  0.014375
# 2      4223.5297    457.0698       0  0.155856
# 3     14522.9563    602.2000       0  0.964660
# 4    124060.1253  16560.5000       0  0.824046

# %%
tarjetas['Edad'].unique()
# Out:
# array([24, 26, 34, 37, 29, 23, 28, 51, 41, 30, 49, 39, 40, 47, 27, 33, 32,
#        54, 58, 22, 31, 25, 42, 45, 57, 56, 44, 35, 53, 43, 38, 63, 36, 52,
#        46, 50, 48, 75, 55, 73, 59, 21, 60, 67, 61, 62, 70, 72],
#       dtype=int64)

# %%
bins = [20,30,40,50,100]
nombres = ['20-30','30-40','40-50','50+']
tarjetas['Rango_edad'] = pd.cut(tarjetas['Edad'], bins, labels=nombres)

# %%
tarjetas.head()
# Out:
#    Limite Cuenta_corriente       Escolaridad Estado_civil  Edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    Valor_factura  Valor_pago  Moroso        iu Rango_edad
# 0       934.0122      0.0000       1  0.155100      20-30
# 1       519.3975      0.0000       1  0.014375      20-30
# 2      4223.5297    457.0698       0  0.155856      30-40
# 3     14522.9563    602.2000       0  0.964660      30-40
# 4    124060.1253  16560.5000       0  0.824046      20-30

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data=tarjetas, x='Rango_edad', y='Limite', palette='inferno');
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3428\3937010731.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=tarjetas, x='Rango_edad', y='Limite', palette='inferno');

# %% [markdown]
# Lo que aprendimos en esta aula:
#
# Aprendimos a crear diferentes gráficos que nos ayudan a analizar variables categóricas: countplot, catplot, swarmplot.
# Aprendimos a usar el parámetro hue, que nos sirve para fraccionar una variable en nuestro gráfico.
# Introducimos los gráficos boxplot y violinplot.
# Creamos y analizamos con boxplot la variable categórica rango_edad.

# %% [markdown]
# ----------------

# %% [markdown]
# Análisis de variables númericas

# %%
plt.figure(figsize=(15,7));
sns.displot(data=tarjetas, x='Limite',hue='Escolaridad', kde=True, palette='inferno');

# %%
plt.figure(figsize=(15,7));
sns.displot(data=tarjetas, x='Limite',hue='Escolaridad', kde=True, col='Escolaridad', palette='inferno');

# %%
plt.figure(figsize=(15,7));
sns.displot(data=tarjetas, x='Limite',hue='Escolaridad', col='Escolaridad',kind='kde', palette='inferno');

# %%
plt.figure(figsize=(15,7));
sns.displot(data=tarjetas, x='Limite',hue='Moroso', col='Escolaridad',kind='kde', palette='inferno');

# %%
plt.figure(figsize=(15,7));
sns.displot(data=tarjetas, x='Limite',hue='Rango_edad', col='Escolaridad',kind='kde', palette='inferno');

# %%
plt.figure(figsize=(15,7));
sns.displot(data=tarjetas, x='Limite',hue='Estado_civil', col='Escolaridad',kind='kde', palette='inferno');

# %%
plt.figure(figsize=(15,7));
sns.displot(data=tarjetas, x='Limite',hue='Cuenta_corriente', col='Escolaridad',kind='kde', palette='inferno');

# %% [markdown]
# -------------------------------------------------

# %% [markdown]
# Dispersión

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(data=tarjetas, x='iu', y='Valor_factura', palette='inferno');
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3428\1657549238.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=tarjetas, x='iu', y='Valor_factura', palette='inferno');

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(data=tarjetas, x='iu', y='Valor_factura',hue='Cuenta_corriente', palette='inferno');

# %%
plt.figure(figsize=(15,7))
sns.lmplot(data=tarjetas, x='iu', y='Valor_factura',hue='Cuenta_corriente');

# %% [markdown]
# ----------------------------------------

# %% [markdown]
# Test de Hipótesis

# %%
plt.figure(figsize=(15,7))
sns.lmplot(data=tarjetas, x='iu', y='Valor_factura',col='Moroso');

# %%
from scipy.stats import ranksums

# %% [markdown]
# H<sup>null<sup>
# La distribución de los grupos morosos y no morosos es la misma

# %% [markdown]
# H<sup>null<sup>
# La distribución de los grupos morosos y no morosos no es la misma

# %%
moroso = tarjetas.query("Moroso == 1")['Valor_factura']

# %%
moroso
# Out:
# 0         934.0122
# 1         519.3975
# 38      10891.0881
# 45        330.6078
# 47       7316.7300
#            ...
# 1448     1619.0147
# 1472    17048.2820
# 1475     4402.0820
# 1478     1851.1628
# 1495      295.0780
# Name: Valor_factura, Length: 117, dtype: float64

# %%
no_moroso = tarjetas.query("Moroso == 0")['Valor_factura']

# %%
no_moroso
# Out:
# 2         4223.5297
# 3        14522.9563
# 4       124060.1253
# 5          114.4180
# 6         4244.3056
#            ...
# 1494     32698.2556
# 1496     23637.8555
# 1497       962.9178
# 1498       864.7592
# 1499     97022.8508
# Name: Valor_factura, Length: 1383, dtype: float64

# %%
resultado = ranksums(moroso, no_moroso)

# %%
print(f'El p_value de nuestro test es {resultado.pvalue}')
# Out:
# El p_value de nuestro test es 0.010391243081223555

# %% [markdown]
# Lo que aprendimos en esta aula:
#
# Hicimos un análisis más profundo de los gráficos de distribución (histograma) usando displot.
# Creamos gráficos diferentes, categorizando nuestra información con el parámetro col.
# Hicimos una introducción al gráfico de dispersión (scatterplot) y al gráfico de modelo linear (lmplot).
# Realizamos un test de hipótesis, para intentar determinar si la diferencia entre los grupos morosos y no morosos es estadísticamente significativa.

# %% [markdown]
# -------------------------------------------------

# %% [markdown]
# JointPlot

# %%
tarjetas.head()
# Out:
#    Limite Cuenta_corriente       Escolaridad Estado_civil  Edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    Valor_factura  Valor_pago  Moroso        iu Rango_edad
# 0       934.0122      0.0000       1  0.155100      20-30
# 1       519.3975      0.0000       1  0.014375      20-30
# 2      4223.5297    457.0698       0  0.155856      30-40
# 3     14522.9563    602.2000       0  0.964660      30-40
# 4    124060.1253  16560.5000       0  0.824046      20-30

# %%
plt.figure(figsize=(15,7))
sns.jointplot(data=tarjetas, x='Edad', y='Limite');

# %%
plt.figure(figsize=(15,7))
sns.jointplot(data=tarjetas, x='Edad', y='Limite', kind='kde');

# %%
plt.figure(figsize=(15,7))
sns.jointplot(data=tarjetas, x='Edad', y='Limite', kind='hex');

# %%
plt.figure(figsize=(15,7))
sns.jointplot(data=tarjetas, x='Edad', y='Limite', kind='kde',hue='Moroso');

# %%
plt.figure(figsize=(15,7))
sns.jointplot(data=tarjetas, x='iu', y='Limite');

# %%
plt.figure(figsize=(15,7))
sns.jointplot(data=tarjetas, x='iu', y='Limite', kind='kde');

# %%
plt.figure(figsize=(15,7))
sns.jointplot(data=tarjetas, x='iu', y='Limite', kind='hex');

# %% [markdown]
# ------------------------------

# %% [markdown]
# Pairplot

# %%
tarjetas.head()
# Out:
#    Limite Cuenta_corriente       Escolaridad Estado_civil  Edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    Valor_factura  Valor_pago  Moroso        iu Rango_edad
# 0       934.0122      0.0000       1  0.155100      20-30
# 1       519.3975      0.0000       1  0.014375      20-30
# 2      4223.5297    457.0698       0  0.155856      30-40
# 3     14522.9563    602.2000       0  0.964660      30-40
# 4    124060.1253  16560.5000       0  0.824046      20-30

# %%
round(tarjetas.describe(), 2)
# Out:
#           Limite     Edad  Valor_factura  Valor_pago   Moroso       iu
# count    1500.00  1500.00        1500.00     1500.00  1500.00  1500.00
# mean    51221.94    35.21       15459.87     1984.87     0.08     0.39
# std     39424.41     9.27       20722.58     5296.77     0.27     0.34
# min      3011.00    21.00          27.70        0.00     0.00     0.00
# 25%     18066.00    28.00        2035.59      407.01     0.00     0.05
# 50%     42154.00    33.50        7701.39      759.37     0.00     0.31
# 75%     72264.00    41.00       20671.57     1705.28     0.00     0.70
# max    210770.00    75.00      141792.51    97022.85     1.00     1.00

# %%
sns.pairplot(data=tarjetas, hue='Escolaridad', palette='inferno');

# %% [markdown]
# Lo que aprendimos en esta aula:
#
# Introducimos el gráfico jointplot con sus opciones: scatter, kde, hex. Esto para analizar la variable de edad y limite.
# Hicimos un análisis descriptivo de las variables en nuestra base de datos.
# Usamos el gráfico pairplot para hacer un análisis conjunto de todas nuestras variables numéricas en la base de datos.
