# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
datos = pd.read_excel('/content/Ventas.xlsx')
datos.head()
# Out:
#     Region      Producto Vendedor  Ventas
# 0  Central    Accesorios    David    8287
# 1  Central    Accesorios    Karen    6909
# 2  Central  Dispositivos    David   11420
# 3  Central  Dispositivos    Karen   12948
# 4  Central      Sistemas    David   20098

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Region    18 non-null     object
#  1   Producto  18 non-null     object
#  2   Vendedor  18 non-null     object
#  3   Ventas    18 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 704.0+ bytes

# %%
datos.isnull().sum()
# Out:
# Region      0
# Producto    0
# Vendedor    0
# Ventas      0
# dtype: int64

# %%
datos.shape
# Out:
# (18, 4)

# %%
datos.iloc[:, [0,3]]
# Out:
#      Region  Ventas
# 0   Central    8287
# 1   Central    6909
# 2   Central   11420
# 3   Central   12948
# 4   Central   20098
# 5   Central   30633
# 6      Este    9323
# 7      Este    7667
# 8      Este   10348
# 9      Este    9312
# 10     Este   13531
# 11     Este   13374
# 12    Oeste    4744
# 13    Oeste    5442
# 14    Oeste   10711
# 15    Oeste    8780
# 16    Oeste   32855
# 17    Oeste   23151

# %%
datos.loc[:, ['Region', 'Ventas']]
# Out:
#      Region  Ventas
# 0   Central    8287
# 1   Central    6909
# 2   Central   11420
# 3   Central   12948
# 4   Central   20098
# 5   Central   30633
# 6      Este    9323
# 7      Este    7667
# 8      Este   10348
# 9      Este    9312
# 10     Este   13531
# 11     Este   13374
# 12    Oeste    4744
# 13    Oeste    5442
# 14    Oeste   10711
# 15    Oeste    8780
# 16    Oeste   32855
# 17    Oeste   23151

# %%
datos.sample()
# Out:
#    Region  Producto Vendedor  Ventas
# 10   Este  Sistemas      Ana   13531

# %%
# Crear subgráficos
fig = make_subplots(rows=1, cols=3, specs=[[{'type': 'domain'}, {'type': 'domain'}, {'type': 'domain'}]])
# Gráfico 1: Ventas por Producto
fig.add_trace(
    go.Pie(labels=datos['Producto'], values=datos['Ventas'], title="Ventas totales por producto"),
    row=1, col=1
)
# Gráfico 2: Ventas totales por Región
fig.add_trace(
    go.Pie(labels=datos['Region'], values=datos['Ventas'], title="Ventas totales por Región"),
    row=1, col=2
)
# Gráfico 2: Ventas totales por Vendedor
fig.add_trace(
    go.Pie(labels=datos['Vendedor'], values=datos['Ventas'], title="Ventas totales por Vendedor"),
    row=1, col=3
)
# Ajustar diseño
fig.update_layout(
    title_text="Comparación de Ventas: Productos y Región",
    title_x=0.5,  # Centrar título
    showlegend=True
)
# Mostrar gráficos
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cb0a77d1-69bb-4799-9904-9a67865950ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb0a77d1-69bb-4799-9904-9a67865950ec")) {                    Plotly.newPlot(                        "cb0a77d1-69bb-4799-9904-9a67865950ec",                        [{"labels":["Accesorios","Accesorios","Dispositivos","Dispositivos","Sistemas","Sistemas","Accesorios","Accesorios","Dispositivos","Dispositivos","Sistemas","Sistemas","Accesorios","Accesorios","Dispositivos","Dispositivos","Sistemas","Sistemas"],"title":{"text":"Ventas totales por producto"},"values":[8287,6909,11420,12948,20098,30633,9323,7667,10348,9312,13531,13374,4744,5442,10711,8780,32855,23151],"type":"pie","domain":{"x":[0.0,0.2888888888888889],"y":[0.0,1.0]}},{"labels":["Central","Central","Central","Central","Central","Central","Este","Este","Este","Este","Este","Este","Oeste","Oeste","Oeste","Oeste","Oeste","Oeste"],"title":{"text":"Ventas totales por Región"},"values":[8287,6909,11420,12948,20098,30633,9323,7667,10348,9312,13531,13374,4744,5442,10711,8780,32855,23151],"type":"pie","domain":{"x":[0.35555555555555557,0.6444444444444445],"y":[0.0,1.0]}},{"labels":["David","Karen","David","Karen","David","Karen","Ana","Lucas","Ana","Lucas","Ana","Lucas","Kevin","Sara","Kevin","Sara","Kevin","Sara"],"title":{"text":"Ventas totales por Vendedor"},"values":[8287,6909,11420,12948,20098,30633,9323,7667,10348,9312,13531,13374,4744,5442,10711,8780,32855,23151],"type":"pie","domain":{"x":[0.7111111111111111,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.111111111 ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder

X = datos[['Producto', 'Region', 'Vendedor']]
y = datos['Ventas']

# Create a OneHotEncoder object
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore') # sparse=False for compatibility with LinearRegression

# Fit the encoder to your categorical features and transform them
encoded_features = encoder.fit_transform(X)

# Create a new DataFrame with the encoded features
encoded_df = pd.DataFrame(encoded_features, columns=encoder.get_feature_names_out(X.columns))

# Now use the encoded DataFrame for training
X_train, X_test, y_train, y_test = train_test_split(encoded_df, y, test_size=0.2, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error # Corrected the module name from 'skearn' to 'sklearn'
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 16586903.79629627

# %%
fig = px.line(y=y_test.values, title='Ventas reales vs. predichas', labels={'x': 'Ventas Reales vs Predicción de Ventas', 'y': 'Ventas totales'},markers=True)
fig.add_scatter(y=y_pred, name='Ventas predichas')
fig.add_scatter(y=y_test, name='Ventas reales', marker=dict(color='blue'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6ee14a23-bbaa-44b8-a318-9aeddf0d16f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ee14a23-bbaa-44b8-a318-9aeddf0d16f2")) {                    Plotly.newPlot(                        "6ee14a23-bbaa-44b8-a318-9aeddf0d16f2",                        [{"hovertemplate":"Ventas Reales vs Predicción de Ventas=%{x}\u003cbr\u003eVentas totales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":[0,1,2,3],"xaxis":"x","y":[8287,6909,10348,30633],"yaxis":"y","type":"scatter"},{"name":"Ventas predichas","y":[7700.777777777781,10458.000000000011,7103.777777777782,24084.444444444456],"type":"scatter"},{"marker":{"color":"blue"},"name":"Ventas reales","y":[8287,6909,10348,30633],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{ ...

# %%
fig = make_subplots(rows=1, cols=2, specs=[[{'type': 'xy'}, {'type': 'xy'}]])
fig.add_trace(
    go.Bar(x=y_test.index, y=y_test.values, name='Ventas reales'),
    row=1, col=1
)
fig.add_trace(
    go.Bar(x=y_test.index, y=y_pred, name='Ventas predichas'),
    row=1, col=2
)
fig.update_layout(
    title_text="Comparación de Ventas: Productos y Región",
    title_x=0.5
    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e441bb65-6578-4256-bcdc-9f7ea2215f1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e441bb65-6578-4256-bcdc-9f7ea2215f1e")) {                    Plotly.newPlot(                        "e441bb65-6578-4256-bcdc-9f7ea2215f1e",                        [{"name":"Ventas reales","x":[0,1,8,5],"y":[8287,6909,10348,30633],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Ventas predichas","x":[0,1,8,5],"y":[7700.777777777781,10458.000000000011,7103.777777777782,24084.444444444456],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogra ...

# %%
fig = px.box(datos, x='Ventas', y='Producto', color='Producto', title='Distribución de Ventas por Producto')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c6f8d435-91ee-4727-b819-29ccb02a5df5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6f8d435-91ee-4727-b819-29ccb02a5df5")) {                    Plotly.newPlot(                        "c6f8d435-91ee-4727-b819-29ccb02a5df5",                        [{"alignmentgroup":"True","hovertemplate":"Producto=%{y}\u003cbr\u003eVentas=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Accesorios","marker":{"color":"#636efa"},"name":"Accesorios","notched":false,"offsetgroup":"Accesorios","orientation":"h","showlegend":true,"x":[8287,6909,9323,7667,4744,5442],"x0":" ","xaxis":"x","y":["Accesorios","Accesorios","Accesorios","Accesorios","Accesorios","Accesorios"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Producto=%{y}\u003cbr\u003eVentas=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Dispositivos","marker":{"color":"#EF553B"},"name":"Dispositivos","notched":false,"offsetgroup":"Dispositivos","orientation":"h","showlegend":true,"x":[11420,12948,10348,9312,10711,8780],"x0":" ","xaxis":"x","y":["Dispositivos","Dispositivos","Dispositivos","Dispositivos","Dispositivos","Dispositivos"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Producto=%{y}\u003cbr\u003eVentas=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sistemas","marker":{"color":"#00cc96"},"name":"Sistemas","notched":false,"offsetgroup":"Sistemas","orientation":"h","showlegend":true,"x":[20098,30633,13531,13374,32855,23151],"x0":" ","xaxis":"x","y":["Sistemas","Sistemas","Sistemas","Sistemas","Sistemas","Sistemas"],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0 ...

# %%
fig = px.box(datos, x='Ventas', y='Vendedor', color='Vendedor', title='Distribución de Ventas por Vendedor')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3fec9795-3784-4acc-82ca-7c673ccd48f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3fec9795-3784-4acc-82ca-7c673ccd48f2")) {                    Plotly.newPlot(                        "3fec9795-3784-4acc-82ca-7c673ccd48f2",                        [{"alignmentgroup":"True","hovertemplate":"Vendedor=%{y}\u003cbr\u003eVentas=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"David","marker":{"color":"#636efa"},"name":"David","notched":false,"offsetgroup":"David","orientation":"h","showlegend":true,"x":[8287,11420,20098],"x0":" ","xaxis":"x","y":["David","David","David"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Vendedor=%{y}\u003cbr\u003eVentas=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Karen","marker":{"color":"#EF553B"},"name":"Karen","notched":false,"offsetgroup":"Karen","orientation":"h","showlegend":true,"x":[6909,12948,30633],"x0":" ","xaxis":"x","y":["Karen","Karen","Karen"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Vendedor=%{y}\u003cbr\u003eVentas=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ana","marker":{"color":"#00cc96"},"name":"Ana","notched":false,"offsetgroup":"Ana","orientation":"h","showlegend":true,"x":[9323,10348,13531],"x0":" ","xaxis":"x","y":["Ana","Ana","Ana"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Vendedor=%{y}\u003cbr\u003eVentas=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Lucas","marker":{"color":"#ab63fa"},"name":"Lucas","notched":false,"offsetgroup":"Lucas","orientation":"h","showlegend":true,"x":[7667,9312,13374],"x0":" ","xaxis":"x","y":["Lucas","Lucas","Lucas"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Vendedor=%{y}\u003cbr\u003eVentas=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kevin","marker":{"color":"#FFA15A"},"name":"Kevin","notched":false,"offsetgroup":"Kevin","orientation":"h","showlegend":true,"x":[4744,10711,32855],"x0":" ","xaxis":"x","y":["Kevin","Kevin","Kevin"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Vendedor=%{y}\u003cbr\u003eVentas=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sara","marker":{"color":"#19d3f3"},"name":"Sara","notched":false,"offsetgroup":"Sara","orientation":"h","showlegend":true,"x":[5442,8780,23151],"x0":" ","xaxis":"x","y":["Sara","Sara","Sara"],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdc ...

# %%
fig = px.box(datos, x='Ventas', y='Region', color='Region', title='Distribución de Ventas por Region')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7fca4047-1a40-4f25-ba52-9fb4a2ba9ddc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7fca4047-1a40-4f25-ba52-9fb4a2ba9ddc")) {                    Plotly.newPlot(                        "7fca4047-1a40-4f25-ba52-9fb4a2ba9ddc",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{y}\u003cbr\u003eVentas=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Central","marker":{"color":"#636efa"},"name":"Central","notched":false,"offsetgroup":"Central","orientation":"h","showlegend":true,"x":[8287,6909,11420,12948,20098,30633],"x0":" ","xaxis":"x","y":["Central","Central","Central","Central","Central","Central"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Region=%{y}\u003cbr\u003eVentas=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Este","marker":{"color":"#EF553B"},"name":"Este","notched":false,"offsetgroup":"Este","orientation":"h","showlegend":true,"x":[9323,7667,10348,9312,13531,13374],"x0":" ","xaxis":"x","y":["Este","Este","Este","Este","Este","Este"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Region=%{y}\u003cbr\u003eVentas=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oeste","marker":{"color":"#00cc96"},"name":"Oeste","notched":false,"offsetgroup":"Oeste","orientation":"h","showlegend":true,"x":[4744,5442,10711,8780,32855,23151],"x0":" ","xaxis":"x","y":["Oeste","Oeste","Oeste","Oeste","Oeste","Oeste"],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"# ...

# %%
fig = px.bar(datos, x='Ventas', y='Producto', color='Producto', title='Distribución de Ventas por Producto')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e5cb9d29-1232-4ae6-b78b-e48ff600118f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e5cb9d29-1232-4ae6-b78b-e48ff600118f")) {                    Plotly.newPlot(                        "e5cb9d29-1232-4ae6-b78b-e48ff600118f",                        [{"alignmentgroup":"True","hovertemplate":"Producto=%{y}\u003cbr\u003eVentas=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Accesorios","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Accesorios","offsetgroup":"Accesorios","orientation":"h","showlegend":true,"textposition":"auto","x":[8287,6909,9323,7667,4744,5442],"xaxis":"x","y":["Accesorios","Accesorios","Accesorios","Accesorios","Accesorios","Accesorios"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Producto=%{y}\u003cbr\u003eVentas=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Dispositivos","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Dispositivos","offsetgroup":"Dispositivos","orientation":"h","showlegend":true,"textposition":"auto","x":[11420,12948,10348,9312,10711,8780],"xaxis":"x","y":["Dispositivos","Dispositivos","Dispositivos","Dispositivos","Dispositivos","Dispositivos"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Producto=%{y}\u003cbr\u003eVentas=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sistemas","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Sistemas","offsetgroup":"Sistemas","orientation":"h","showlegend":true,"textposition":"auto","x":[20098,30633,13531,13374,32855,23151],"xaxis":"x","y":["Sistemas","Sistemas","Sistemas","Sistemas","Sistemas","Sistemas"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888 ...

# %%
fig = px.bar(datos, x='Ventas', y='Vendedor', color='Vendedor', title='Distribución de Ventas por Vendedor')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9c26b3ad-6a0b-4c62-ae3a-71cbc99811f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c26b3ad-6a0b-4c62-ae3a-71cbc99811f2")) {                    Plotly.newPlot(                        "9c26b3ad-6a0b-4c62-ae3a-71cbc99811f2",                        [{"alignmentgroup":"True","hovertemplate":"Vendedor=%{y}\u003cbr\u003eVentas=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"David","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"David","offsetgroup":"David","orientation":"h","showlegend":true,"textposition":"auto","x":[8287,11420,20098],"xaxis":"x","y":["David","David","David"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vendedor=%{y}\u003cbr\u003eVentas=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Karen","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Karen","offsetgroup":"Karen","orientation":"h","showlegend":true,"textposition":"auto","x":[6909,12948,30633],"xaxis":"x","y":["Karen","Karen","Karen"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vendedor=%{y}\u003cbr\u003eVentas=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ana","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Ana","offsetgroup":"Ana","orientation":"h","showlegend":true,"textposition":"auto","x":[9323,10348,13531],"xaxis":"x","y":["Ana","Ana","Ana"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vendedor=%{y}\u003cbr\u003eVentas=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Lucas","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Lucas","offsetgroup":"Lucas","orientation":"h","showlegend":true,"textposition":"auto","x":[7667,9312,13374],"xaxis":"x","y":["Lucas","Lucas","Lucas"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vendedor=%{y}\u003cbr\u003eVentas=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kevin","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Kevin","offsetgroup":"Kevin","orientation":"h","showlegend":true,"textposition":"auto","x":[4744,10711,32855],"xaxis":"x","y":["Kevin","Kevin","Kevin"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vendedor=%{y}\u003cbr\u003eVentas=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sara","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Sara","offsetgroup":"Sara","orientation":"h","showlegend":true,"textposition":"auto","x":[5442,8780,23151],"xaxis":"x","y":["Sara","Sara","Sara"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666," ...

# %%
fig = px.bar(datos, x='Ventas', y='Region', color='Region', title='Distribución de Ventas por Región')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="35d609a1-c4b9-4ab0-95f5-5de70c1b3ce9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35d609a1-c4b9-4ab0-95f5-5de70c1b3ce9")) {                    Plotly.newPlot(                        "35d609a1-c4b9-4ab0-95f5-5de70c1b3ce9",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{y}\u003cbr\u003eVentas=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Central","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Central","offsetgroup":"Central","orientation":"h","showlegend":true,"textposition":"auto","x":[8287,6909,11420,12948,20098,30633],"xaxis":"x","y":["Central","Central","Central","Central","Central","Central"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{y}\u003cbr\u003eVentas=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Este","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Este","offsetgroup":"Este","orientation":"h","showlegend":true,"textposition":"auto","x":[9323,7667,10348,9312,13531,13374],"xaxis":"x","y":["Este","Este","Este","Este","Este","Este"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{y}\u003cbr\u003eVentas=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oeste","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Oeste","offsetgroup":"Oeste","orientation":"h","showlegend":true,"textposition":"auto","x":[4744,5442,10711,8780,32855,23151],"xaxis":"x","y":["Oeste","Oeste","Oeste","Oeste","Oeste","Oeste"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0, ...

# %% [markdown]
# #Objetivo del análisis:
# - Evaluar el desempeño de las ventas para:
#
# - Identificar las regiones con mayores ingresos.
#
# - Determinar qué productos tienen mejor desempeño.
# Evaluar la contribución de cada vendedor al total de ventas.
#
# #Informe del Análisis
#
# En este análisis, **primero importé las bibliotecas necesarias, incluyendo pandas, numpy, matplotlib, seaborn, warnings, plotly y sklearn**. Luego, **cargué los datos de ventas desde un archivo Excel usando pandas y realicé una exploración inicial de los datos**. Verifiqué el tipo de datos de cada columna, busqué valores nulos, examiné las dimensiones del conjunto de datos y seleccioné subconjuntos específicos de los datos utilizando `iloc` y `loc`.
#
# Para comprender mejor las ventas, **creé varias visualizaciones**.  Utilicé gráficos de pastel para comparar las ventas totales por producto, región y vendedor. Para analizar más a fondo las ventas, **implementé un modelo de regresión lineal**. Codifiqué las características categóricas usando OneHotEncoder, dividí los datos en conjuntos de entrenamiento y prueba, entrené el modelo y luego evalué su rendimiento utilizando el error cuadrático medio (MSE).
#
# Para visualizar el rendimiento del modelo, **creé gráficos de líneas y barras que comparan las ventas reales con las predichas**. Además, **generé gráficos de caja y barras para mostrar la distribución de ventas por producto, vendedor y región.**
