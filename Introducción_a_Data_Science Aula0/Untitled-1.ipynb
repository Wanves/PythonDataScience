# %% [markdown]
# ### Analizando las películas en forma general

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
notas = pd.read_csv('ratings.csv')
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
def grafico():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,6), facecolor='indigo')
    plt.plot(notas['movieId'].head(20),notas['rating'].head(20))
    plt.xticks(color='w', size=15, fontweight='bold')
    plt.yticks(color='w', size=15, fontweight='bold')
    plt.show()
grafico()

# %%
notas.shape
# Out:
# (100836, 4)

# %%
notas.shape[0]
# Out:
# 100836

# %%
notas.shape[1]
# Out:
# 4

# %%
notas.sample(1)
# Out:
#       userId  movieId  rating   timestamp
# 1113       9     5956     4.0  1044656962

# %%
dict = {
    'userId':'usuarioId',
    'movieId':'peliculaId',
    'rating':'nota',
    'timestamp':'momento'
}

notas = notas.rename(columns=dict)
notas.sample()
# Out:
#        usuarioId  peliculaId  nota     momento
# 60812        392        3298   4.0  1027524346

# %%
# notas.columns = ['usuarioId', 'peliculaId', 'nota', 'momento']
# notas

# %%
notas[['nota','peliculaId']].sort_index()
# Out:
#         nota  peliculaId
# 0        4.0           1
# 1        4.0           3
# 2        4.0           6
# 3        5.0          47
# 4        5.0          50
# ...      ...         ...
# 100831   4.0      166534
# 100832   5.0      168248
# 100833   5.0      168250
# 100834   5.0      168252
# 100835   3.0      170875
#
# [100836 rows x 2 columns]

# %%
notas_valor = notas['nota'].unique()
notas_valor
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
def grafico():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,6), facecolor='indigo')
    plt.plot(notas_valor, notas['peliculaId'].head(10) )
    plt.title('Datos de Películas',color='w', size=20, fontweight='bold',pad=20)
    plt.xlabel('Notas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Id Películas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='w', size=15, fontweight='bold')
    plt.yticks(color='w', size=15, fontweight='bold')
    plt.show()
grafico()

# %%
notas['nota'].value_counts()
# Out:
# nota
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: count, dtype: int64

# %%
notas['nota'].median()
# Out:
# 3.5

# %%
round(notas['nota'].mean(), 2)
# Out:
# 3.5

# %%
notas[['nota']].describe()
# Out:
#                 nota
# count  100836.000000
# mean        3.501557
# std         1.042529
# min         0.500000
# 25%         3.000000
# 50%         3.500000
# 75%         4.000000
# max         5.000000

# %%
notas[['nota']].std()
# Out:
# nota    1.042529
# dtype: float64

# %%
notas[['nota']].min()
# Out:
# nota    0.5
# dtype: float64

# %%
notas[['nota']].max()
# Out:
# nota    5.0
# dtype: float64

# %%
def grafico():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,6), facecolor='indigo')
    plt.plot(notas['nota'].head(30) )
    plt.title('Datos de Películas',color='w', size=20, fontweight='bold',pad=20)
    plt.xlabel('Notas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Id Películas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='w', size=15, fontweight='bold')
    plt.yticks(color='w', size=15, fontweight='bold')
    plt.show()
grafico()

# %%
notas.head(n=10)
# Out:
#    usuarioId  peliculaId  nota    momento
# 0          1           1   4.0  964982703
# 1          1           3   4.0  964981247
# 2          1           6   4.0  964982224
# 3          1          47   5.0  964983815
# 4          1          50   5.0  964982931
# 5          1          70   3.0  964982400
# 6          1         101   5.0  964980868
# 7          1         110   4.0  964982176
# 8          1         151   5.0  964984041
# 9          1         157   5.0  964984100

# %%
notas['nota']
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: nota, Length: 100836, dtype: float64

# %% [markdown]
# ### Visualización de los Datos

# %%
def grafico():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,6), facecolor='indigo')
    notas['nota'].plot()
    # plt.plot(notas['nota'].head(30) )
    plt.title('Datos de Películas',color='w', size=20, fontweight='bold',pad=20)
    plt.xlabel('Notas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Id Películas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='w', size=15, fontweight='bold')
    plt.yticks(color='w', size=15, fontweight='bold')
    plt.show()
grafico()

# %%
def grafico():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,8), facecolor='indigo')
    plt.hist(notas['nota'])
    plt.title('Datos de Películas',color='w', size=20, fontweight='bold',pad=20)
    plt.xlabel('Notas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Id Películas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='w', size=15, fontweight='bold')
    plt.yticks(color='w', size=15, fontweight='bold')
    plt.show()
grafico()

# %%
print(f'Promedio: {notas['nota'].mean()}')
print(f'Mediana: {notas['nota'].median()}')
# Out:
# Promedio: 3.501556983616962
# Mediana: 3.5

# %%
notas[['nota']].describe()
# Out:
#                 nota
# count  100836.000000
# mean        3.501557
# std         1.042529
# min         0.500000
# 25%         3.000000
# 50%         3.500000
# 75%         4.000000
# max         5.000000

# %%
def grafico():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,5), facecolor='indigo')
    sns.boxplot(notas['nota'])
    plt.title('Datos de Películas',color='w', size=20, fontweight='bold',pad=20)
    plt.xlabel('Notas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Id Películas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='w', size=15, fontweight='bold')
    plt.yticks(color='w', size=15, fontweight='bold')
    plt.show()
grafico()

# %% [markdown]
# Importar Pandas que es una biblioteca de análisis de datos.
# Leer datos CSV.
# Hacer upload de archivos para Google Colab.
# Renombrar columnas.
# Contar datos.
# Mejorar la visualización de las informaciones.

# %% [markdown]
# ### Analizando algunas notas especificas por pelicula

# %%
peliculas = pd.read_csv('movies.csv')
peliculas.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# metodo para cambiar los títulos de las columnas
dict_pelicula = {
    'movieId':'peliculaId',
    'title':'título',
    'genres':'generos'
}
peliculas.rename(columns=dict_pelicula, inplace=True)
peliculas.head()
# Out:
#    peliculaId                              título  \
# 0           1                    Toy Story (1995)
# 1           2                      Jumanji (1995)
# 2           3             Grumpier Old Men (1995)
# 3           4            Waiting to Exhale (1995)
# 4           5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
notas.query('peliculaId == 1')
# Out:
#        usuarioId  peliculaId  nota     momento
# 0              1           1   4.0   964982703
# 516            5           1   4.0   847434962
# 874            7           1   4.5  1106635946
# 1434          15           1   2.5  1510577970
# 1667          17           1   4.5  1305696483
# ...          ...         ...   ...         ...
# 97364        606           1   2.5  1349082950
# 98479        607           1   4.0   964744033
# 98666        608           1   2.5  1117408267
# 99497        609           1   3.0   847221025
# 99534        610           1   5.0  1479542900
#
# [215 rows x 4 columns]

# %%
notas.query('peliculaId == 1').nota.describe()
# Out:
# count    215.000000
# mean       3.920930
# std        0.834859
# min        0.500000
# 25%        3.500000
# 50%        4.000000
# 75%        4.500000
# max        5.000000
# Name: nota, dtype: float64

# %%
# para ver el promedio de una pelicula
round(notas.query('peliculaId == 1').nota.mean(), 6)
# Out:
# 3.92093

# %%
# para ver el promedio de todas las peliculas
promedio_por_pelicula = notas.groupby('peliculaId').nota.mean()
promedio_por_pelicula
# Out:
# peliculaId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
#             ...
# 193581    4.000000
# 193583    3.500000
# 193585    3.500000
# 193587    3.500000
# 193609    4.000000
# Name: nota, Length: 9724, dtype: float64

# %%
def promedio_pelicula():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,8), facecolor='indigo')
    sns.histplot(data=promedio_por_pelicula, bins=20, kde=True)
    plt.title('Datos de Películas',color='w', size=20, fontweight='bold',pad=20)
    plt.xlabel('Notas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Id Películas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='w', size=15, fontweight='bold')
    plt.yticks(color='w', size=15, fontweight='bold')
    plt.show()
promedio_pelicula()

# %%
def promedio_pelicula():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,8), facecolor='indigo')
    plt.hist(promedio_por_pelicula, color='c')
    plt.title('Datos de Películas',color='w', size=20, fontweight='bold',pad=20)
    plt.xlabel('Notas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Id Películas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='w', size=15, fontweight='bold')
    plt.yticks(color='w', size=15, fontweight='bold')
    plt.legend(promedio_por_pelicula)
    plt.show()

promedio_pelicula()

# %%
def promedio_pelicula():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,8), facecolor='indigo')
    n, bins, patches = plt.hist(promedio_por_pelicula, color='c', alpha=0.7)  # alpha controla la opacidad de las barras
    for i in range(len(bins)-1):
        plt.text(bins[i] + (bins[i+1]-bins[i])/2, n[i], f'{int(n[i])}', ha='center', va='bottom', fontsize=12, color='b', fontweight='bold')
    plt.title('Datos de Películas',color='w', size=20, fontweight='bold',pad=20)
    plt.xlabel('Notas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Id Películas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='w', size=15, fontweight='bold')
    plt.yticks(color='w', size=15, fontweight='bold')
    plt.show()
promedio_pelicula()

# %%
def promedio_pelicula():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,8), facecolor='indigo')
    sns.boxplot(promedio_por_pelicula)
    plt.title('Datos de Películas',color='w', size=20, fontweight='bold',pad=20)
    plt.xlabel('Notas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Id Películas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='w', size=15, fontweight='bold')
    plt.yticks(color='w', size=15, fontweight='bold')
    plt.legend(promedio_por_pelicula, loc='best')
    plt.show()

promedio_pelicula()

# %%
promedio_por_pelicula.describe()
# Out:
# count    9724.000000
# mean        3.262448
# std         0.869874
# min         0.500000
# 25%         2.800000
# 50%         3.416667
# 75%         3.911765
# max         5.000000
# Name: nota, dtype: float64

# %%
def promedio_pelicula_displot():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,8), facecolor='indigo')
    sns.distplot(promedio_por_pelicula, bins=10)
    plt.title('Datos de Películas',color='w', size=20, fontweight='bold',pad=20)
    plt.xlabel('Notas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Id Películas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='w', size=15, fontweight='bold')
    plt.yticks(color='w', size=15, fontweight='bold')
    plt.show()
promedio_pelicula_displot()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10736\74866351.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(promedio_por_pelicula, bins=10)

# %%
def promedio_pelicula_hist():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,5), facecolor='indigo')
    plt.hist(promedio_por_pelicula, color='c')
    n, bins, patches = plt.hist(promedio_por_pelicula, color='c', alpha=0.7)
    for i in range(len(bins)-1):
        plt.text(bins[i] + (bins[i+1]-bins[i])/2, n[i], f'{int(n[i])}', ha='center', va='bottom', fontsize=12, color='b', fontweight='bold')
    plt.title('Histograma Promedio peliculas',color='w', size=20, fontweight='bold',pad=20)
    plt.xlabel('Id Películas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Promedio',color='w', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='w', size=15, fontweight='bold')
    plt.yticks(color='w', size=15, fontweight='bold')
    plt.show()
promedio_pelicula_hist()

# %%
def promedio_pelicula_hist():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,5), facecolor='indigo')
    sns.boxplot(x=promedio_por_pelicula, color='orange')
    plt.title('Histograma Promedio peliculas',color='w', size=20, fontweight='bold',pad=20)
    plt.xlabel('Id Películas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Promedio',color='w', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='w', size=15, fontweight='bold')
    plt.yticks(color='w', size=15, fontweight='bold')
    plt.show()
promedio_pelicula_hist()
