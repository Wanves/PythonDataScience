# %% [markdown]
# ### Analizando las películas en forma general

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
notas = pd.read_csv('ratings.csv')
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
def grafico():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,6), facecolor='indigo')
    plt.plot(notas['movieId'].head(20),notas['rating'].head(20))
    plt.xticks(color='w', size=15, fontweight='bold')
    plt.yticks(color='w', size=15, fontweight='bold')
    plt.show()
grafico()

# %%
notas.shape
# Out:
# (100836, 4)

# %%
notas.shape[0]
# Out:
# 100836

# %%
notas.shape[1]
# Out:
# 4

# %%
notas.sample(1)
# Out:
#        userId  movieId  rating   timestamp
# 16294     105     1407     4.0  1448214382

# %%
dict = {
    'userId':'usuarioId',
    'movieId':'peliculaId',
    'rating':'nota',
    'timestamp':'momento'
}

notas = notas.rename(columns=dict)
notas.sample()
# Out:
#       usuarioId  peliculaId  nota     momento
# 7084         48        5349   4.0  1127128913

# %%
# notas.columns = ['usuarioId', 'peliculaId', 'nota', 'momento']
# notas

# %%
notas[['nota','peliculaId']].sort_index()
# Out:
#         nota  peliculaId
# 0        4.0           1
# 1        4.0           3
# 2        4.0           6
# 3        5.0          47
# 4        5.0          50
# ...      ...         ...
# 100831   4.0      166534
# 100832   5.0      168248
# 100833   5.0      168250
# 100834   5.0      168252
# 100835   3.0      170875
#
# [100836 rows x 2 columns]

# %%
notas_valor = notas['nota'].unique()
notas_valor
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
def grafico():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,6), facecolor='indigo')
    plt.plot(notas_valor, notas['peliculaId'].head(10) )
    plt.title('Datos de Películas',color='w', size=20, fontweight='bold',pad=20)
    plt.xlabel('Notas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Id Películas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='w', size=15, fontweight='bold')
    plt.yticks(color='w', size=15, fontweight='bold')
    plt.show()
grafico()

# %%
notas['nota'].value_counts()
# Out:
# nota
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: count, dtype: int64

# %%
notas['nota'].median()
# Out:
# 3.5

# %%
round(notas['nota'].mean(), 2)
# Out:
# 3.5

# %%
notas[['nota']].describe()
# Out:
#                 nota
# count  100836.000000
# mean        3.501557
# std         1.042529
# min         0.500000
# 25%         3.000000
# 50%         3.500000
# 75%         4.000000
# max         5.000000

# %%
notas[['nota']].std()
# Out:
# nota    1.042529
# dtype: float64

# %%
notas[['nota']].min()
# Out:
# nota    0.5
# dtype: float64

# %%
notas[['nota']].max()
# Out:
# nota    5.0
# dtype: float64

# %%
def grafico():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,6), facecolor='indigo')
    plt.plot(notas['nota'].head(30) )
    plt.title('Datos de Películas',color='w', size=20, fontweight='bold',pad=20)
    plt.xlabel('Notas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Id Películas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='w', size=15, fontweight='bold')
    plt.yticks(color='w', size=15, fontweight='bold')
    plt.show()
grafico()

# %%
notas.head(n=10)
# Out:
#    usuarioId  peliculaId  nota    momento
# 0          1           1   4.0  964982703
# 1          1           3   4.0  964981247
# 2          1           6   4.0  964982224
# 3          1          47   5.0  964983815
# 4          1          50   5.0  964982931
# 5          1          70   3.0  964982400
# 6          1         101   5.0  964980868
# 7          1         110   4.0  964982176
# 8          1         151   5.0  964984041
# 9          1         157   5.0  964984100

# %%
notas['nota']
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: nota, Length: 100836, dtype: float64

# %% [markdown]
# ### Visualización de los Datos

# %%
def grafico():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,6), facecolor='indigo')
    notas['nota'].plot()
    # plt.plot(notas['nota'].head(30) )
    plt.title('Datos de Películas',color='w', size=20, fontweight='bold',pad=20)
    plt.xlabel('Notas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Id Películas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='w', size=15, fontweight='bold')
    plt.yticks(color='w', size=15, fontweight='bold')
    plt.show()
grafico()

# %%
def grafico():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,8), facecolor='indigo')
    plt.hist(notas['nota'])
    plt.title('Datos de Películas',color='w', size=20, fontweight='bold',pad=20)
    plt.xlabel('Notas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Id Películas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='w', size=15, fontweight='bold')
    plt.yticks(color='w', size=15, fontweight='bold')
    plt.show()
grafico()

# %%
print(f'Promedio: {notas['nota'].mean()}')
print(f'Mediana: {notas['nota'].median()}')
# Out:
# Promedio: 3.501556983616962
# Mediana: 3.5

# %%
notas[['nota']].describe()
# Out:
#                 nota
# count  100836.000000
# mean        3.501557
# std         1.042529
# min         0.500000
# 25%         3.000000
# 50%         3.500000
# 75%         4.000000
# max         5.000000

# %%
def grafico():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,5), facecolor='indigo')
    sns.boxplot(notas['nota'])
    plt.title('Datos de Películas',color='w', size=20, fontweight='bold',pad=20)
    plt.xlabel('Notas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Id Películas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='w', size=15, fontweight='bold')
    plt.yticks(color='w', size=15, fontweight='bold')
    plt.show()
grafico()

# %% [markdown]
# Importar Pandas que es una biblioteca de análisis de datos.
# Leer datos CSV.
# Hacer upload de archivos para Google Colab.
# Renombrar columnas.
# Contar datos.
# Mejorar la visualización de las informaciones.

# %% [markdown]
# ### Analizando algunas notas especificas por pelicula

# %%
peliculas = pd.read_csv('movies.csv')
peliculas.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# metodo para cambiar los títulos de las columnas
dict_pelicula = {
    'movieId':'peliculaId',
    'title':'título',
    'genres':'generos'
}
peliculas.rename(columns=dict_pelicula, inplace=True)
peliculas.head()
# Out:
#    peliculaId                              título  \
# 0           1                    Toy Story (1995)
# 1           2                      Jumanji (1995)
# 2           3             Grumpier Old Men (1995)
# 3           4            Waiting to Exhale (1995)
# 4           5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
notas.query('peliculaId == 1')
# Out:
#        usuarioId  peliculaId  nota     momento
# 0              1           1   4.0   964982703
# 516            5           1   4.0   847434962
# 874            7           1   4.5  1106635946
# 1434          15           1   2.5  1510577970
# 1667          17           1   4.5  1305696483
# ...          ...         ...   ...         ...
# 97364        606           1   2.5  1349082950
# 98479        607           1   4.0   964744033
# 98666        608           1   2.5  1117408267
# 99497        609           1   3.0   847221025
# 99534        610           1   5.0  1479542900
#
# [215 rows x 4 columns]

# %%
notas.query('peliculaId == 1').nota.describe()
# Out:
# count    215.000000
# mean       3.920930
# std        0.834859
# min        0.500000
# 25%        3.500000
# 50%        4.000000
# 75%        4.500000
# max        5.000000
# Name: nota, dtype: float64

# %%
# para ver el promedio de una pelicula
round(notas.query('peliculaId == 1').nota.mean(), 6)
# Out:
# 3.92093

# %%
# para ver el promedio de todas las peliculas
promedio_por_pelicula = notas.groupby('peliculaId').nota.mean()
promedio_por_pelicula
# Out:
# peliculaId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
#             ...
# 193581    4.000000
# 193583    3.500000
# 193585    3.500000
# 193587    3.500000
# 193609    4.000000
# Name: nota, Length: 9724, dtype: float64

# %%
def promedio_pelicula():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,8), facecolor='indigo')
    sns.histplot(data=promedio_por_pelicula, bins=20, kde=True)
    plt.title('Datos de Películas',color='w', size=20, fontweight='bold',pad=20)
    plt.xlabel('Notas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Id Películas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='w', size=15, fontweight='bold')
    plt.yticks(color='w', size=15, fontweight='bold')
    plt.show()
promedio_pelicula()

# %%
def promedio_pelicula():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,8), facecolor='indigo')
    plt.hist(promedio_por_pelicula, color='c')
    plt.title('Datos de Películas',color='w', size=20, fontweight='bold',pad=20)
    plt.xlabel('Notas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Id Películas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='w', size=15, fontweight='bold')
    plt.yticks(color='w', size=15, fontweight='bold')
    plt.legend(promedio_por_pelicula)
    plt.show()

promedio_pelicula()

# %%
def promedio_pelicula():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,8), facecolor='indigo')
    n, bins, patches = plt.hist(promedio_por_pelicula, color='c', alpha=0.7)  # alpha controla la opacidad de las barras
    for i in range(len(bins)-1):
        plt.text(bins[i] + (bins[i+1]-bins[i])/2, n[i], f'{int(n[i])}', ha='center', va='bottom', fontsize=12, color='b', fontweight='bold')
    plt.title('Datos de Películas',color='w', size=20, fontweight='bold',pad=20)
    plt.xlabel('Notas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Id Películas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='w', size=15, fontweight='bold')
    plt.yticks(color='w', size=15, fontweight='bold')
    plt.show()
promedio_pelicula()

# %%
def promedio_pelicula():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,8), facecolor='indigo')
    sns.boxplot(promedio_por_pelicula)
    plt.title('Datos de Películas',color='w', size=20, fontweight='bold',pad=20)
    plt.xlabel('Notas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Id Películas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='w', size=15, fontweight='bold')
    plt.yticks(color='w', size=15, fontweight='bold')
    plt.legend(promedio_por_pelicula, loc='best')
    plt.show()

promedio_pelicula()

# %%
promedio_por_pelicula.describe()
# Out:
# count    9724.000000
# mean        3.262448
# std         0.869874
# min         0.500000
# 25%         2.800000
# 50%         3.416667
# 75%         3.911765
# max         5.000000
# Name: nota, dtype: float64

# %%
def promedio_pelicula_displot():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,8), facecolor='indigo')
    sns.distplot(promedio_por_pelicula, bins=10)
    plt.title('Datos de Películas',color='lightblue', size=20, fontweight='bold',pad=20)
    plt.xlabel('Notas',color='lightblue', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Id Películas',color='lightblue', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold')
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    plt.show()
promedio_pelicula_displot()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9168\1031312218.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(promedio_por_pelicula, bins=10)

# %%
def promedio_pelicula_hist():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,5), facecolor='indigo')
    plt.hist(promedio_por_pelicula, color='c')
    n, bins, patches = plt.hist(promedio_por_pelicula, color='c', alpha=0.7)
    for i in range(len(bins)-1):
        plt.text(bins[i] + (bins[i+1]-bins[i])/2, n[i], f'{int(n[i])}', ha='center', va='bottom', fontsize=12, color='b', fontweight='bold')
    plt.title('Histograma Promedio peliculas',color='lightblue', size=20, fontweight='bold',pad=20)
    plt.xlabel('Id Películas',color='lightblue', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Promedio',color='lightblue', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold')
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    plt.show()
promedio_pelicula_hist()

# %%
def promedio_pelicula_hist():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,5), facecolor='indigo')
    sns.boxplot(x=promedio_por_pelicula, color='orange')
    plt.title('Histograma Promedio peliculas',color='lightblue', size=20, fontweight='bold',pad=20)
    plt.xlabel('Id Películas',color='lightblue', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Promedio',color='lightblue', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold')
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    plt.show()
promedio_pelicula_hist()

# %% [markdown]
# Lo que aprendimos
#
#
# Trabajar filtros usando query.
# Lo que son bins.
# Filtrar una única columna.

# %% [markdown]
# ### Tipos de Variables

# %%
tmdb = pd.read_csv('tmdb_5000_movies.csv')
tmdb.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
# ...

# %%
tmdb.columns = ['presupuesto','genero','páginaweb','id','palabras_clave', 'lenguaje_original','título_original','descripción_general','popularidad','Compañías_de_producción','países_de_producción','fecha_de_lanzamiento','ganancia','tiempo_de _ejecución','lenguajes_hablados','estado', 'eslogan','título','voto_promedio','recuento_votos']
tmdb.head(2)
# Out:
#    presupuesto                                             genero  \
# 0    237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1    300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                       páginaweb     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                       palabras_clave lenguaje_original  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                             título_original  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                  descripción_general  popularidad  \
# 0  In the 22nd century, a paraplegic Marine is di...   150.437577
# 1  Captain Barbossa, long believed to be dead, ha...   139.082615
#
# ...

# %%
tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   presupuesto              4803 non-null   int64
#  1   genero                   4803 non-null   object
#  2   páginaweb                1712 non-null   object
#  3   id                       4803 non-null   int64
#  4   palabras_clave           4803 non-null   object
#  5   lenguaje_original        4803 non-null   object
#  6   título_original          4803 non-null   object
#  7   descripción_general      4800 non-null   object
#  8   popularidad              4803 non-null   float64
#  9   Compañías_de_producción  4803 non-null   object
#  10  países_de_producción     4803 non-null   object
#  11  fecha_de_lanzamiento     4802 non-null   object
#  12  ganancia                 4803 non-null   int64
#  13  tiempo_de _ejecución     4801 non-null   float64
# ...

# %%
tmdb.dropna().head()
# Out:
#    presupuesto                                             genero  \
# 0    237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1    300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2    245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3    250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4    260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                       páginaweb      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                       palabras_clave lenguaje_original  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   presupuesto              4803 non-null   int64
#  1   genero                   4803 non-null   object
#  2   páginaweb                1712 non-null   object
#  3   id                       4803 non-null   int64
#  4   palabras_clave           4803 non-null   object
#  5   lenguaje_original        4803 non-null   object
#  6   título_original          4803 non-null   object
#  7   descripción_general      4800 non-null   object
#  8   popularidad              4803 non-null   float64
#  9   Compañías_de_producción  4803 non-null   object
#  10  países_de_producción     4803 non-null   object
#  11  fecha_de_lanzamiento     4802 non-null   object
#  12  ganancia                 4803 non-null   int64
#  13  tiempo_de _ejecución     4801 non-null   float64
# ...

# %%
tmdb.describe()
# Out:
#         presupuesto             id  popularidad      ganancia  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08
# min    0.000000e+00       5.000000     0.000000  0.000000e+00
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09
#
#        tiempo_de _ejecución  voto_promedio  recuento_votos
# count           4801.000000    4803.000000     4803.000000
# mean             106.875859       6.092172      690.217989
# std               22.611935       1.194612     1234.585891
# min                0.000000       0.000000        0.000000
# 25%               94.000000       5.600000       54.000000
# ...

# %%
tmdb1 = tmdb[['presupuesto',	'id', 'popularidad', 'ganancia', 'tiempo_de _ejecución', 'voto_promedio', 'recuento_votos']].dropna()
tmdb1.head()
# Out:
#    presupuesto      id  popularidad    ganancia  tiempo_de _ejecución  \
# 0    237000000   19995   150.437577  2787965087                 162.0
# 1    300000000     285   139.082615   961000000                 169.0
# 2    245000000  206647   107.376788   880674609                 148.0
# 3    250000000   49026   112.312950  1084939099                 165.0
# 4    260000000   49529    43.926995   284139100                 132.0
#
#    voto_promedio  recuento_votos
# 0            7.2           11800
# 1            6.9            4500
# 2            6.3            4466
# 3            7.6            9106
# 4            6.1            2124

# %%
tmdb1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4801 entries, 0 to 4802
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   presupuesto           4801 non-null   int64
#  1   id                    4801 non-null   int64
#  2   popularidad           4801 non-null   float64
#  3   ganancia              4801 non-null   int64
#  4   tiempo_de _ejecución  4801 non-null   float64
#  5   voto_promedio         4801 non-null   float64
#  6   recuento_votos        4801 non-null   int64
# dtypes: float64(3), int64(4)
# memory usage: 300.1 KB

# %%
# variables clasificación categóricas nominales
tmdb['lenguaje_original'].unique()
# Out:
# array(['en', 'ja', 'fr', 'zh', 'es', 'de', 'hi', 'ru', 'ko', 'te', 'cn',
#        'it', 'nl', 'ta', 'sv', 'th', 'da', 'xx', 'hu', 'cs', 'pt', 'is',
#        'tr', 'nb', 'af', 'pl', 'he', 'ar', 'vi', 'ky', 'id', 'ro', 'fa',
#        'no', 'sl', 'ps', 'el'], dtype=object)

# %%
# variable cuantitativa continua
tmdb['presupuesto'].sort_index()
# Out:
# 0       237000000
# 1       300000000
# 2       245000000
# 3       250000000
# 4       260000000
#           ...
# 4798       220000
# 4799         9000
# 4800            0
# 4801            0
# 4802            0
# Name: presupuesto, Length: 4803, dtype: int64

# %%
# variable cuantitativa de intervalos
tmdb['recuento_votos'].sort_index()
# Out:
# 0       11800
# 1        4500
# 2        4466
# 3        9106
# 4        2124
#         ...
# 4798      238
# 4799        5
# 4800        6
# 4801        7
# 4802       16
# Name: recuento_votos, Length: 4803, dtype: int64

# %%
def promedio_bar():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,5), facecolor='indigo')
    sns.barplot(tmdb['presupuesto'].head(20))
    plt.title('Peliculas',color='lightblue', size=20, fontweight='bold',pad=20)
    plt.xlabel('Presupuesto',color='lightblue', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Promedio',color='lightblue', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold')
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    plt.show()
promedio_bar()

# %% [markdown]
# Lo que aprendimos
#
#
# Identificar el tipo de variable observando su contenido.
# El concepto y ejemplos de categorías ordinales.
# El concepto y ejemplos de categorías cuantitativas.

# %% [markdown]
# ### Visualizando gráficos por categoría

# %%
# transformo en un dataframe
contador_de_idiomas = tmdb['lenguaje_original'].value_counts().to_frame()
contador_de_idiomas.head(2)
# Out:
#                    count
# lenguaje_original
# en                  4505
# fr                    70

# %%
# resetéo el indice
contador_de_idiomas = tmdb.lenguaje_original.value_counts().reset_index()
dict_ci = {
    'count':'total'
}
contador_de_idiomas = contador_de_idiomas.rename(columns=dict_ci)
contador_de_idiomas.head()
# Out:
#   lenguaje_original  total
# 0                en   4505
# 1                fr     70
# 2                es     32
# 3                zh     27
# 4                de     27

# %%
def idiomas_bar():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,5), facecolor='indigo')
    sns.barplot(data=contador_de_idiomas, x='lenguaje_original', y='total')
    plt.title('Peliculas',color='lightblue', size=20, fontweight='bold',pad=20)
    plt.xlabel('lenguaje_original',color='lightblue', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Idiomas',color='lightblue', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold')
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    plt.show()
idiomas_bar()

# %%
def idiomas_catplot():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,5), facecolor='indigo')
    sns.countplot(x=tmdb['lenguaje_original'], hue=tmdb['lenguaje_original'], palette='viridis', legend=False)
    plt.title('Peliculas',color='lightblue', size=20, fontweight='bold',pad=20)
    plt.xlabel('lenguaje_original',color='lightblue', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Cantidad de Películas',color='lightblue', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold', rotation=45)  # Rotamos las etiquetas para mayor legibilidad
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    plt.show()

idiomas_catplot()

# %%
def idiomas_catplot():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,5), facecolor='indigo')
    plt.pie(contador_de_idiomas.total.head(), labels=contador_de_idiomas.lenguaje_original.head())
    plt.title('Peliculas',color='w', size=20, fontweight='bold',pad=20)
    plt.xlabel('lenguaje_original',color='w', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Cantidad de Películas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='w', size=15, fontweight='bold', rotation=45)  # Rotamos las etiquetas para mayor legibilidad
    plt.yticks(color='w', size=15, fontweight='bold')
    plt.show()

idiomas_catplot()

# %%
total_por_idioma = tmdb['lenguaje_original'].value_counts()
total_general = total_por_idioma.sum()
total_ingles = total_por_idioma.loc['en']
total_diferencia = total_general - total_ingles
print(total_general, total_ingles, total_diferencia)
# Out:
# 4803 4505 298

# %%
datos = {
    'idioma':['ingles','otros'],
    'total':[total_ingles, total_diferencia]
}
datos
# Out:
# {'idioma': ['ingles', 'otros'], 'total': [4505, 298]}

# %%
datos = pd.DataFrame(datos)
datos
# Out:
#    idioma  total
# 0  ingles   4505
# 1   otros    298

# %%
def idiomas_barplot():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,8), facecolor='indigo')
    sns.barplot(data=datos, x='idioma', y='total')
    plt.title('Peliculas',color='lightblue', size=20, fontweight='bold',pad=20)
    plt.xlabel('lenguaje_original',color='lightblue', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Cantidad de Películas',color='lightblue', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold'), #rotation=45)  # Rotamos las etiquetas para mayor legibilidad
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    plt.show()

idiomas_barplot()

# %%
tmdb.query('lenguaje_original == "en"')
# Out:
#       presupuesto                                             genero  \
# 0       237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1       300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2       245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3       250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4       260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...           ...                                                ...
# 4797            0  [{"id": 10769, "name": "Foreign"}, {"id": 53, ...
# 4799         9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800            0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801            0                                                 []
# 4802            0                [{"id": 99, "name": "Documentary"}]
#
#                                               páginaweb      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
tmdb.query('lenguaje_original != "en"').head()
# Out:
#      presupuesto                                             genero  \
# 97      15000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 235     97250400  [{"id": 14, "name": "Fantasy"}, {"id": 12, "na...
# 317     94000000  [{"id": 18, "name": "Drama"}, {"id": 36, "name...
# 474            0  [{"id": 9648, "name": "Mystery"}, {"id": 18, "...
# 492      8000000  [{"id": 35, "name": "Comedy"}, {"id": 16, "nam...
#
#                                              páginaweb      id  \
# 97                                                 NaN  315011
# 235  http://www.asterixauxjeuxolympiques.com/index.php    2395
# 317               http://www.theflowersofwarmovie.com/   76758
# 474                                                NaN  330770
# 492                                                NaN  293644
#
#                                         palabras_clave lenguaje_original  \
# 97   [{"id": 1299, "name": "monster"}, {"id": 7671,...                ja
# ...

# %%
tmdb.query('lenguaje_original != "en"').lenguaje_original.value_counts()
# Out:
# lenguaje_original
# fr    70
# es    32
# zh    27
# de    27
# hi    19
# ja    16
# it    14
# cn    12
# ko    11
# ru    11
# pt     9
# da     7
# sv     5
# fa     4
# nl     4
# he     3
# th     3
# ro     2
# id     2
# ar     2
# cs     2
# ta     2
# tr     1
# nb     1
# af     1
# pl     1
# is     1
# hu     1
# vi     1
# ky     1
# xx     1
# te     1
# no     1
# sl     1
# ps     1
# el     1
# Name: count, dtype: int64

# %%
peliculas_sin_idioma_ingles = tmdb.query('lenguaje_original != "en"')
peliculas_sin_idioma_ingles
# Out:
#       presupuesto                                             genero  \
# 97       15000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 235      97250400  [{"id": 14, "name": "Fantasy"}, {"id": 12, "na...
# 317      94000000  [{"id": 18, "name": "Drama"}, {"id": 36, "name...
# 474             0  [{"id": 9648, "name": "Mystery"}, {"id": 18, "...
# 492       8000000  [{"id": 35, "name": "Comedy"}, {"id": 16, "nam...
# ...           ...                                                ...
# 4739            0  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4751            0  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 4790            0  [{"id": 18, "name": "Drama"}, {"id": 10769, "n...
# 4792        20000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4798       220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                               páginaweb      id  \
# 97                                                  NaN  315011
# ...

# %%
def idiomas_barplot():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,8), facecolor='indigo')
    sns.catplot(data=peliculas_sin_idioma_ingles, x='lenguaje_original',kind= 'count' ,)
    plt.title('Peliculas',color='w', size=20, fontweight='bold',pad=20)
    plt.xlabel('lenguaje_original',color='w', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Cantidad de Películas',color='w', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='k', size=15, fontweight='bold'), #rotation=45)  # Rotamos las etiquetas para mayor legibilidad
    plt.yticks(color='k', size=15, fontweight='bold')
    plt.show()

idiomas_barplot()

# %% [markdown]
# Lo que es una Series.
# Instalar seaborn.
# Transformar un conjunto de datos en dataframe con la función to_frame().
# Remover el índice para generar dos columnas usando la función reset_index().

# %%
def idiomas_barplot():
    sns.set(style="darkgrid")
    # plt.figure(figsize=(20,8), facecolor='indigo')
    sns.catplot(data=peliculas_sin_idioma_ingles, x='lenguaje_original',kind= 'count', aspect=3 , legend='full', color='b')
    
    plt.title('Peliculas',color='k', size=20, fontweight='bold',pad=20)
    plt.xlabel('lenguaje_original',color='k', size=20, fontweight='bold',labelpad=20)
    plt.ylabel('Cantidad de Películas',color='k', size=20, fontweight='bold',labelpad=20)
    plt.xticks(color='b', size=15, fontweight='bold') #rotation=45)  # Rotamos las etiquetas para mayor legibilidad
    plt.yticks(color='b', size=15, fontweight='bold')
    plt.show()

idiomas_barplot()

# %%
def idiomas_barplot():
    sns.set(style="darkgrid")
    # Obtener el objeto de los ejes para establecer su color
    sns.catplot(data=peliculas_sin_idioma_ingles, x='lenguaje_original', kind='count', aspect=3, hue='lenguaje_original', palette='deep', legend=False, order=total_por_idioma.index)
    plt.title('Peliculas', color='k', size=20, fontweight='bold', pad=20)
    plt.xlabel('lenguaje_original', color='k', size=20, fontweight='bold', labelpad=20)
    plt.ylabel('Cantidad de Películas', color='k', size=20, fontweight='bold', labelpad=20)
    plt.xticks(color='k', size=15, fontweight='bold')  # Rotamos las etiquetas para mayor legibilidad
    plt.yticks(color='k', size=15, fontweight='bold')
    plt.show()
idiomas_barplot()

# %%
total_idiomas_otras_peliculas = tmdb.query('lenguaje_original != "en"').lenguaje_original.value_counts()

# %%
def idiomas_barplot():
    sns.set(style="darkgrid")
    # Obtener el objeto de los ejes para establecer su color
    sns.catplot(data=peliculas_sin_idioma_ingles, x='lenguaje_original', kind='count', aspect=3, hue='lenguaje_original', palette='viridis', legend=False, order=total_idiomas_otras_peliculas.index)
    plt.title('Peliculas', color='k', size=20, fontweight='bold', pad=20)
    plt.xlabel('lenguaje_original', color='k', size=20, fontweight='bold', labelpad=20)
    plt.ylabel('Cantidad de Películas', color='k', size=20, fontweight='bold', labelpad=20)
    plt.xticks(color='k', size=15, fontweight='bold')  # Rotamos las etiquetas para mayor legibilidad
    plt.yticks(color='k', size=15, fontweight='bold')
    plt.show()
idiomas_barplot()

# %% [markdown]
# Lo que aprendimos
#
# Re-dimensionar los gráficos.
# Ordenar los gráficos.
# Alterar el tono/customizar los gráficos.

# %%
peliculas.head()
# Out:
#    peliculaId                              título  \
# 0           1                    Toy Story (1995)
# 1           2                      Jumanji (1995)
# 2           3             Grumpier Old Men (1995)
# 3           4            Waiting to Exhale (1995)
# 4           5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
peliculas.query('peliculaId >= 10 & peliculaId <= 15')
# Out:
#     peliculaId                              título  \
# 9           10                    GoldenEye (1995)
# 10          11      American President, The (1995)
# 11          12  Dracula: Dead and Loving It (1995)
# 12          13                        Balto (1995)
# 13          14                        Nixon (1995)
# 14          15             Cutthroat Island (1995)
#
#                          generos
# 9      Action|Adventure|Thriller
# 10          Comedy|Drama|Romance
# 11                 Comedy|Horror
# 12  Adventure|Animation|Children
# 13                         Drama
# 14      Action|Adventure|Romance

# %%
peliculas.query('generos == "Adventure|Animation|Children"').value_counts()
# Out:
# peliculaId  título                                                       generos
# 13          Balto (1995)                                                 Adventure|Animation|Children    1
# 2085        101 Dalmatians (One Hundred and One Dalmatians) (1961)       Adventure|Animation|Children    1
# 2089        Rescuers Down Under, The (1990)                              Adventure|Animation|Children    1
# 2899        Gulliver's Travels (1939)                                    Adventure|Animation|Children    1
# 3615        Dinosaur (2000)                                              Adventure|Animation|Children    1
# 3945        Digimon: The Movie (2000)                                    Adventure|Animation|Children    1
# 5109        Return to Never Land (2002)                                  Adventure|Animation|Children    1
# 6889        Brother Bear (2003)                                          Adventure|Animation|Children    1
# ...

# %%
peliculas.query('generos == "Adventure|Animation|Children"').value_counts().sum()
# Out:
# 16

# %%
peliculas.query('generos == "Action|Adventure|Romance"').value_counts()
# Out:
# peliculaId  título                                generos
# 15          Cutthroat Island (1995)               Action|Adventure|Romance    1
# 940         Adventures of Robin Hood, The (1938)  Action|Adventure|Romance    1
# 8167        Captain Blood (1935)                  Action|Adventure|Romance    1
# 25962       King Solomon's Mines (1950)           Action|Adventure|Romance    1
# 101577      Host, The (2013)                      Action|Adventure|Romance    1
# Name: count, dtype: int64

# %%
peliculas.query('generos == "Action|Adventure|Romance"').value_counts().sum()
# Out:
# 5

# %%
peliculas.head(2)
# Out:
#    peliculaId            título                                      generos
# 0           1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1           2    Jumanji (1995)                   Adventure|Children|Fantasy

# %%
notas_toy_story = notas.query('peliculaId == 1').value_counts()
notas_toy_story
# Out:
# usuarioId  peliculaId  nota  momento
# 1          1           4.0   964982703     1
# 380        1           5.0   1493420345    1
# 382        1           4.5   1515162628    1
# 385        1           4.0   834691642     1
# 389        1           5.0   857934174     1
#                                           ..
# 214        1           3.0   853937855     1
# 216        1           3.0   975211713     1
# 217        1           4.0   955942540     1
# 219        1           3.5   1194681084    1
# 610        1           5.0   1479542900    1
# Name: count, Length: 215, dtype: int64

# %%
notas_toy_story = notas.query('peliculaId == 1').value_counts().sum()
notas_toy_story
# Out:
# 215

# %%
notas_toy_story = notas.query('peliculaId == 1').mean()
notas_toy_story
# Out:
# usuarioId     3.065302e+02
# peliculaId    1.000000e+00
# nota          3.920930e+00
# momento       1.129835e+09
# dtype: float64

# %%
notas_jumanji = notas.query('peliculaId == 2').value_counts()
notas_jumanji
# Out:
# usuarioId  peliculaId  nota  momento
# 6          2           4.0   845553522     1
# 432        2           4.0   1316391739    1
# 477        2           4.0   1200939962    1
# 476        2           4.0   835021693     1
# 475        2           4.5   1498031744    1
#                                           ..
# 221        2           3.5   1111177796    1
# 219        2           2.5   1194740185    1
# 217        2           2.0   955942327     1
# 202        2           4.0   974923336     1
# 608        2           2.0   1117490786    1
# Name: count, Length: 110, dtype: int64

# %%
notas_jumanji = notas.query('peliculaId == 2').mean()
notas_jumanji
# Out:
# usuarioId     3.295545e+02
# peliculaId    2.000000e+00
# nota          3.431818e+00
# momento       1.135805e+09
# dtype: float64

# %%
print(len(notas_toy_story), len(notas_jumanji))
# Out:
# 4 4

# %%
notas_toy_story = notas.query('peliculaId == 1')
notas_jumanji = notas.query('peliculaId == 2')
print(len(notas_toy_story), len(notas_jumanji))
# Out:
# 215 110

# %%
print(f'El promedio de Nota la película Toy Story es: {round(notas_toy_story.nota.mean(), 2)}\nEl promedio de Nota la película Jumanji es: {round(notas_jumanji.nota.mean(), 2)}')
# Out:
# El promedio de Nota la película Toy Story es: 3.92
# El promedio de Nota la película Jumanji es: 3.43

# %%
print(f'El promedio de Nota la película Toy Story es: {notas_toy_story.nota.median():.2f}\nEl promedio de Nota la película Jumanji es: {notas_jumanji.nota.median():.2f}')
# Out:
# El promedio de Nota la película Toy Story es: 4.00
# El promedio de Nota la película Jumanji es: 3.50

# %%
pelicula1= np.append(
np.array([2.5]*10),
np.array([3.5]*10)
)
pelicula2= np.append(
np.array([1]*10),
np.array([5]*10)
)

# %%
print(f'{pelicula1.mean()} --- {pelicula2.mean()}')
# Out:
# 3.0 --- 3.0

# %%
print(f'{np.median(pelicula1)} --- {np.median(pelicula2)}')
# Out:
# 3.0 --- 3.0

# %%
def distplot_peliculas():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,5), facecolor='indigo')
    # Obtener el objeto de los ejes para establecer su color
    sns.distplot(pelicula1)
    sns.distplot(pelicula2)
    plt.title('Peliculas', color='lightblue', size=20, fontweight='bold', pad=20)
    # plt.xlabel('lenguaje_original', color='lightblue', size=20, fontweight='bold', labelpad=20)
    plt.ylabel('Density', color='lightblue', size=20, fontweight='bold', labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold')  # Rotamos las etiquetas para mayor legibilidad
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    plt.show()
distplot_peliculas()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9168\544770579.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(pelicula1)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9168\544770579.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(pelicula2)

# %%
def histograma_peliculas():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,5), facecolor='indigo')
    # Obtener el objeto de los ejes para establecer su color
    plt.hist(pelicula1)
    plt.hist(pelicula2)
    plt.title('Peliculas', color='lightblue', size=20, fontweight='bold', pad=20)
    plt.xlabel('Notas', color='lightblue', size=20, fontweight='bold', labelpad=20)
    plt.ylabel('Cantidad de Usuarios', color='lightblue', size=20, fontweight='bold', labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold')  # Rotamos las etiquetas para mayor legibilidad
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    plt.show()
histograma_peliculas()

# %%
def boxplot_peliculas():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,5), facecolor='indigo')
    # Obtener el objeto de los ejes para establecer su color
    plt.boxplot([pelicula1, pelicula2])
    plt.title('Peliculas', color='lightblue', size=20, fontweight='bold', pad=20)
    # plt.xlabel('Notas', color='lightblue', size=20, fontweight='bold', labelpad=20)
    plt.ylabel('Notas', color='lightblue', size=20, fontweight='bold', labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold')  # Rotamos las etiquetas para mayor legibilidad
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    plt.show()
boxplot_peliculas()

# %% [markdown]
# ### Desviación Estándar

# %%
def boxplot_notas():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,5), facecolor='indigo')
    # Obtener el objeto de los ejes para establecer su color
    plt.boxplot([notas_toy_story['nota'],notas_jumanji['nota']])
    plt.title('Peliculas', color='lightblue', size=20, fontweight='bold', pad=20)
    # plt.xlabel('Notas', color='lightblue', size=20, fontweight='bold', labelpad=20)
    plt.ylabel('Notas', color='lightblue', size=20, fontweight='bold', labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold')  # Rotamos las etiquetas para mayor legibilidad
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    plt.show()
boxplot_notas()

# %%
def boxplot_notas():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,5), facecolor='indigo')
    # Obtener el objeto de los ejes para establecer su color
    sns.boxplot(data=notas.query('peliculaId in (1,2)') , x='peliculaId', y='nota', color='b')
    plt.title('Peliculas', color='lightblue', size=20, fontweight='bold', pad=20)
    plt.xlabel('Pelicula(Id)', color='lightblue', size=20, fontweight='bold', labelpad=20)
    plt.ylabel('Notas', color='lightblue', size=20, fontweight='bold', labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold')  # Rotamos las etiquetas para mayor legibilidad
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    plt.show()
boxplot_notas()

# %%
def boxplot_notas():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,5), facecolor='indigo')
    # Obtener el objeto de los ejes para establecer su color
    sns.boxplot(data=notas.query('peliculaId in (1,2,3,4,5)') , x='peliculaId', y='nota', color='b')
    plt.title('Peliculas', color='lightblue', size=20, fontweight='bold', pad=20)
    plt.xlabel('Pelicula(Id)', color='lightblue', size=20, fontweight='bold', labelpad=20)
    plt.ylabel('Notas', color='lightblue', size=20, fontweight='bold', labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold')  # Rotamos las etiquetas para mayor legibilidad
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    plt.show()
boxplot_notas()

# %%
print(f'Desviación Estándar de la película Toy Story es: {notas_toy_story.nota.std():.2f}\nDesviación Estándar de la película Jumanji es: {notas_jumanji.nota.std():.2f}')
# Out:
# Desviación Estándar de la película Toy Story es: 0.83
# Desviación Estándar de la película Jumanji es: 0.88

# %%
def boxplot_notas():
    sns.set(style="darkgrid")
    plt.figure(figsize=(20,5), facecolor='indigo')
    # Obtener el objeto de los ejes para establecer su color
    sns.boxplot(data=notas.query('peliculaId in (1,2,3,4,5)') , x='peliculaId', y='nota', color='b')
    plt.title('Peliculas', color='lightblue', size=20, fontweight='bold', pad=20)
    plt.xlabel('Pelicula(Id)', color='lightblue', size=20, fontweight='bold', labelpad=20)
    plt.ylabel('Notas', color='lightblue', size=20, fontweight='bold', labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold')  # Rotamos las etiquetas para mayor legibilidad
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    plt.show()
boxplot_notas()

# %%
print(pelicula1.mean(), pelicula2.mean())
print(f'{np.median(pelicula1)} {np.median(pelicula2)}')
print(f'{np.std(pelicula1)} {np.std(pelicula2)}')
# Out:
# 3.0 3.0
# 3.0 3.0
# 0.5 2.0

# %% [markdown]
# Lo que aprendimos
#
#
# Comparar la media de las peliculas.
# Juntar arrays con np.append().
# El concepto y ejemplos prácticos de dispersión de datos.
# Desviación estándar.
